# %% [markdown]
# This Jupyter Notebook includes code adapted from the RouteNet project.
#
# Original author:
# - Krzysztof Rusek
#   AGH University of Science and Technology, Department of Communications, Krakow, Poland.
#   Email: krusek@agh.edu.pl
#
# This code is licensed under the BSD 3-Clause License. See the LICENSE file in this repository for details.

# %%
# TF2.x
import tensorflow.compat.v1 as tf

# TF1.x
# import tensorflow as tf

from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

from tensorflow import keras

import numpy as np
from dataclasses import dataclass, field
from typing import Optional
import glob

# %%
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.15.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
def parse(serialized, target='delay'): #Target is the name of predicted variable
    
    with tf.name_scope('parse'):    
        features = tf.parse_single_example(
            serialized,
            features={
                'traffic':tf.VarLenFeature(tf.float32),
                target:tf.VarLenFeature(tf.float32),
                'links':tf.VarLenFeature(tf.int64),
                'paths':tf.VarLenFeature(tf.int64),
                'sequances':tf.VarLenFeature(tf.int64),
                'n_links':tf.FixedLenFeature([],tf.int64), 
                'n_paths':tf.FixedLenFeature([],tf.int64),
                'n_total':tf.FixedLenFeature([],tf.int64)
            }
        )
        
        for k in ['traffic',target,'links','paths','sequances']:
            features[k] = tf.sparse_tensor_to_dense(features[k])
            if k == 'delay':
                features[k] = (features[k]-2.8)/2.5
            if k == 'traffic':
                #features[k] = (features[k]-0.76)/.008
                features[k] = (features[k]-0.5)/.5
            if k == 'drops':
                features[k] = (features[k])/12000/(0.5*features['traffic']+0.5) #loss rate
            #if k == 'jitter':
                #features[k] = (tf.math.log( features[k] )-2.0)/2.0 #logjitter
            
    return {k:v for k,v in features.items() if k is not target },features[target]

# %%
def tfrecord_input_fn(filenames,hparams,shuffle_buf=1000, target='delay'):
    
    files = tf.data.Dataset.from_tensor_slices(filenames)
    files = files.shuffle(len(filenames))

    ds = files.interleave(tf.data.TFRecordDataset, cycle_length=4)

    if shuffle_buf:
        ds = ds.shuffle(shuffle_buf).repeat()
    
    # ds = ds.map(lambda buf:parse(buf,target), num_parallel_calls=2)
    ds = ds.map(lambda buf:parse(buf,target), num_parallel_calls=tf.data.AUTOTUNE)

    shapes=(
        {
        'traffic':[hparams.node_count*(hparams.node_count-1)],
        'links':[-1],
        'paths':[-1],
        'sequances':[-1],
        'n_links':[],
        'n_paths':[],
        'n_total':[]
        },
        [hparams.node_count*(hparams.node_count-1)]
    )
        
    ds = ds.padded_batch(hparams.batch_size,shapes)
    ds = ds.prefetch(1)
    
    return ds

# %%
class ComnetModel(tf.keras.Model):
    def __init__(self,hparams, output_units=1):
        super(ComnetModel, self).__init__()
        self.hparams = hparams

        self.edge_update = tf.nn.rnn_cell.GRUCell(hparams.link_state_dim, dtype=tf.float32)
        self.path_update = tf.nn.rnn_cell.GRUCell(hparams.path_state_dim, dtype=tf.float32)
        # self.edge_update = tf.keras.layers.GRUCell(hparams.link_state_dim)
        # self.path_update = tf.keras.layers.GRUCell(hparams.path_state_dim)
        
        self.readout = tf.keras.models.Sequential()
        
        self.readout.add(keras.layers.Dense(hparams.readout_units, activation=tf.nn.selu, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
        self.readout.add(keras.layers.Dropout(rate=hparams.dropout_rate))
        
        self.readout.add(keras.layers.Dense(hparams.readout_units, activation=tf.nn.selu, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
        self.readout.add(keras.layers.Dropout(rate=hparams.dropout_rate))
        
        self.readout.add(keras.layers.Dense(output_units, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
            
    def build(self, input_shape=None):
        del input_shape
        self.edge_update.build(tf.TensorShape([None,self.hparams.path_state_dim]))
        self.path_update.build(tf.TensorShape([None,self.hparams.link_state_dim]))
        self.readout.build(input_shape = [None,self.hparams.path_state_dim])
        self.built = True

    def call(self, inputs, training=False):
        f_ = inputs
        shape = tf.stack([f_['n_links'],self.hparams.link_state_dim], axis=0)
        link_state = tf.zeros(shape)
        shape = tf.stack([f_['n_paths'],self.hparams.path_state_dim-1], axis=0)
        path_state = tf.concat([tf.expand_dims(f_['traffic'],axis=1), tf.zeros(shape)], axis=1)

        links = f_['links'][0:f_["n_total"]]
        paths = f_['paths'][0:f_["n_total"]]
        seqs=  f_['sequances'][0:f_["n_total"]]
        
        for _ in range(self.hparams.T):
        
            h_tild = tf.gather(link_state,links)

            ids=tf.stack([paths, seqs], axis=1)            
            max_len = tf.reduce_max(seqs)+1
            shape = tf.stack([f_['n_paths'], max_len, self.hparams.link_state_dim])
            lens = tf.segment_sum(data=tf.ones_like(paths), segment_ids=paths)

            link_inputs = tf.scatter_nd(ids, h_tild, shape)
            outputs, path_state = tf.nn.dynamic_rnn(self.path_update,link_inputs,sequence_length=lens,initial_state=path_state,dtype=tf.float32)
            m = tf.gather_nd(outputs,ids)
            m = tf.unsorted_segment_sum(m, links ,f_['n_links'])
            _,link_state = self.edge_update(m, link_state)
        
        r = self.readout(path_state,training=training)
        
        return r

# %%
def streaming_pearson_correlation_dl(labels, predictions, weights=None):
    """
    Compute streaming Pearson correlation with distributed training compatibility.
    Handles both single-replica and multi-replica contexts.
    Returns (value_tensor, update_op) for use in eval_metric_ops.
    """
    global learning_strategy
    
    # Cast inputs to float32 for compatibility
    labels = tf.cast(labels, tf.float32)
    predictions = tf.cast(predictions, tf.float32)

    # Batch-wise computations
    batch_size = tf.cast(tf.size(labels), tf.float32)
    batch_mean_x = tf.reduce_mean(predictions)
    batch_mean_y = tf.reduce_mean(labels)
    batch_mean_x_squared = tf.reduce_mean(tf.square(predictions))
    batch_mean_y_squared = tf.reduce_mean(tf.square(labels))
    batch_mean_xy = tf.reduce_mean(predictions * labels)

    # Use tf.metrics to accumulate streaming values
    mean_x, update_mean_x = tf.metrics.mean(batch_mean_x, weights)
    mean_y, update_mean_y = tf.metrics.mean(batch_mean_y, weights)
    mean_x_squared, update_mean_x_squared = tf.metrics.mean(batch_mean_x_squared, weights)
    mean_y_squared, update_mean_y_squared = tf.metrics.mean(batch_mean_y_squared, weights)
    mean_xy, update_mean_xy = tf.metrics.mean(batch_mean_xy, weights)
    count, update_count = tf.metrics.mean(batch_size, weights)

    # Compute Pearson correlation
    def compute_correlation():
        covariance = mean_xy - mean_x * mean_y
        variance_x = mean_x_squared - tf.square(mean_x)
        variance_y = mean_y_squared - tf.square(mean_y)
        denominator = tf.sqrt(variance_x * variance_y)
        return tf.where(tf.greater(denominator, 0), covariance / denominator, 0.0)

    rho = compute_correlation()

    # Group all update ops
    update_op = tf.group(
        update_mean_x, update_mean_y, update_mean_x_squared,
        update_mean_y_squared, update_mean_xy, update_count
    )

    # Distributed training compatibility
    if learning_strategy and learning_strategy.num_replicas_in_sync > 1:
        
        # Aggregate distributed values using the strategy context
        def aggregate_rho(learning_strategy, rho):
            return learning_strategy.reduce(tf.distribute.ReduceOp.MEAN, rho, axis=None)

        # Use merge_call to enter cross-replica context
        rho = tf.distribute.get_replica_context().merge_call(lambda ctx: aggregate_rho(ctx, rho))

    return rho, update_op

# %%
def model_fn(features, labels, mode, params):
    
    model = ComnetModel(params)
    model.build()
    #model.summary()

    predictions = tf.map_fn(lambda x: model(x,training=mode==tf.estimator.ModeKeys.TRAIN), features,dtype=tf.float32)
    #predictions = model(features,training=mode==tf.estimator.ModeKeys.TRAIN)
    predictions = tf.squeeze(predictions)

    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions={'predictions':predictions})

    loss =  tf.losses.mean_squared_error(labels=labels, predictions = predictions, reduction=tf.losses.Reduction.MEAN)

    regularization_loss = sum(model.losses)
    total_loss = loss + regularization_loss
    
    tf.summary.scalar('loss', loss)
    tf.summary.scalar('regularization_loss', regularization_loss)

    if mode == tf.estimator.ModeKeys.EVAL:
        
        return tf.estimator.EstimatorSpec(
            mode,
            loss=loss,
            eval_metric_ops=
            {
                'label/mean':tf.metrics.mean(labels),
                'prediction/mean': tf.metrics.mean(predictions),
                
                'mae':tf.metrics.mean_absolute_error(labels, predictions),
                'mse': tf.metrics.mean_squared_error(labels=labels, predictions=predictions),
                
                #'rho_contrib':tf.contrib.metrics.streaming_pearson_correlation(labels=labels,predictions=predictions),
                'rho': streaming_pearson_correlation_dl(labels, predictions)
            }
        )
    
    assert mode == tf.estimator.ModeKeys.TRAIN

    trainables = model.variables
    grads = tf.gradients(total_loss, trainables)
    grad_var_pairs = zip(grads, trainables)

    summaries = [tf.summary.histogram(var.op.name, var) for var in trainables]
    summaries += [tf.summary.histogram(g.op.name, g) for g in grads if g is not None]

    optimizer=tf.train.AdamOptimizer(params.learning_rate)
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    
    with tf.control_dependencies(update_ops):
        train_op = optimizer.apply_gradients(grad_var_pairs, global_step=tf.train.get_global_step())

    return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op,)

# %%
def train(args):
    
    print(args.hparams)
    tf.logging.set_verbosity('INFO')

    global learning_strategy
    learning_strategy = args.strategy

    my_checkpointing_config = tf.estimator.RunConfig(
        train_distribute=args.strategy,
        eval_distribute=args.strategy,
        save_checkpoints_steps=1000,
        keep_checkpoint_max=10
    )

    estimator = tf.estimator.Estimator(
        model_fn=model_fn, 
        model_dir=args.model_dir, 
        params=args.hparams, 
        warm_start_from=args.warm, 
        config=my_checkpointing_config)

    train_spec = tf.estimator.TrainSpec(input_fn=lambda:tfrecord_input_fn(args.train,args.hparams,shuffle_buf=args.shuffle_buf,target=args.target),max_steps=args.train_steps)
    eval_spec = tf.estimator.EvalSpec(input_fn=lambda:tfrecord_input_fn(args.eval_,args.hparams,shuffle_buf=None,target=args.target),steps=args.eval_steps,throttle_secs=1)

    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %%
tfrecord_train_files = glob.glob("nsfnet/tfrecords/train/*.tfrecords")
tfrecord_eval_files = glob.glob("nsfnet/tfrecords/evaluate/*.tfrecords")

@dataclass
class HyperParams:
    node_count: int = 14
    link_state_dim: int = 16
    path_state_dim: int = 32
    T: int = 8
    readout_units: int = 256
    learning_rate: float = 0.001
    batch_size: int = 32
    dropout_rate: float = 0.5
    l2: float = 0.1
    l2_2: float = 0.01

@dataclass
class Args:
    target: str = "delay"
    strategy: Optional[str] = None #tf.distribute.MirroredStrategy()
    hparams: HyperParams = HyperParams()
    train: list = field(default_factory=lambda: tfrecord_train_files)
    eval_: list = field(default_factory=lambda: tfrecord_eval_files)
    model_dir: str = "cp_dl_models_04012025_centralized"
    train_steps: int = 50000
    eval_steps: Optional[int] = None
    shuffle_buf: int = 30000
    warm: Optional[str] = None

args = Args()

# %%
# %time train(args)
# Out:
# HyperParams(node_count=14, link_state_dim=16, path_state_dim=32, T=8, readout_units=256, learning_rate=0.001, batch_size=32, dropout_rate=0.5, l2=0.1, l2_2=0.01)
# INFO:tensorflow:Using config: {'_model_dir': 'cp_dl_models_04012025_centralized', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 10, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.1409761, step = 0
# INFO:tensorflow:global_step/sec: 2.05075
# INFO:tensorflow:loss = 0.1004433, step = 100 (48.764 sec)
# INFO:tensorflow:global_step/sec: 2.12811
# INFO:tensorflow:loss = 0.072271064, step = 200 (46.990 sec)
# INFO:tensorflow:global_step/sec: 2.12266
# INFO:tensorflow:loss = 0.08432599, step = 300 (47.111 sec)
# INFO:tensorflow:global_step/sec: 2.14996
# INFO:tensorflow:loss = 0.043990944, step = 400 (46.513 sec)
# INFO:tensorflow:global_step/sec: 2.1328
# INFO:tensorflow:loss = 0.04880686, step = 500 (46.887 sec)
# INFO:tensorflow:global_step/sec: 2.13321
# INFO:tensorflow:loss = 0.040900532, step = 600 (46.878 sec)
# INFO:tensorflow:global_step/sec: 2.13963
# INFO:tensorflow:loss = 0.059641916, step = 700 (46.737 sec)
# INFO:tensorflow:global_step/sec: 2.13323
# INFO:tensorflow:loss = 0.029695174, step = 800 (46.877 sec)
# INFO:tensorflow:global_step/sec: 2.16424
# INFO:tensorflow:loss = 0.041658398, step = 900 (46.206 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T09:00:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.10278s
# INFO:tensorflow:Finished evaluation at 2025-01-06-09:06:16
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, label/mean = -0.9424406, loss = 0.008447144, mae = 0.04791881, mse = 0.008447407, prediction/mean = -0.9145604, rho = 0.94855416
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: cp_dl_models_04012025_centralized/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 0.246498
# INFO:tensorflow:loss = 0.03291271, step = 1000 (405.683 sec)
# INFO:tensorflow:global_step/sec: 2.14022
# INFO:tensorflow:loss = 0.0508935, step = 1100 (46.725 sec)
# INFO:tensorflow:global_step/sec: 2.14783
# INFO:tensorflow:loss = 0.033090457, step = 1200 (46.559 sec)
# INFO:tensorflow:global_step/sec: 2.14607
# INFO:tensorflow:loss = 0.050598145, step = 1300 (46.597 sec)
# INFO:tensorflow:global_step/sec: 2.1261
# INFO:tensorflow:loss = 0.050464246, step = 1400 (47.034 sec)
# INFO:tensorflow:global_step/sec: 2.12165
# INFO:tensorflow:loss = 0.042760752, step = 1500 (47.133 sec)
# INFO:tensorflow:global_step/sec: 2.11834
# INFO:tensorflow:loss = 0.067184485, step = 1600 (47.207 sec)
# INFO:tensorflow:global_step/sec: 2.11312
# INFO:tensorflow:loss = 0.028262839, step = 1700 (47.323 sec)
# INFO:tensorflow:global_step/sec: 2.11374
# INFO:tensorflow:loss = 0.041164313, step = 1800 (47.309 sec)
# INFO:tensorflow:global_step/sec: 2.10292
# INFO:tensorflow:loss = 0.013872253, step = 1900 (47.553 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2000...
# INFO:tensorflow:Saving checkpoints for 2000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T09:14:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.46526s
# INFO:tensorflow:Finished evaluation at 2025-01-06-09:20:06
# INFO:tensorflow:Saving dict for global step 2000: global_step = 2000, label/mean = -0.94243944, loss = 0.009946412, mae = 0.036537416, mse = 0.009947904, prediction/mean = -0.94107336, rho = 0.9503307
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: cp_dl_models_04012025_centralized/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 0.247223
# INFO:tensorflow:loss = 0.03061049, step = 2000 (404.493 sec)
# INFO:tensorflow:global_step/sec: 2.1459
# INFO:tensorflow:loss = 0.0406889, step = 2100 (46.601 sec)
# INFO:tensorflow:global_step/sec: 2.16286
# INFO:tensorflow:loss = 0.04666545, step = 2200 (46.235 sec)
# INFO:tensorflow:global_step/sec: 2.16591
# INFO:tensorflow:loss = 0.010792336, step = 2300 (46.169 sec)
# INFO:tensorflow:global_step/sec: 2.13486
# INFO:tensorflow:loss = 0.02409468, step = 2400 (46.842 sec)
# INFO:tensorflow:global_step/sec: 2.12195
# INFO:tensorflow:loss = 0.01786222, step = 2500 (47.126 sec)
# INFO:tensorflow:global_step/sec: 2.15876
# INFO:tensorflow:loss = 0.03348978, step = 2600 (46.323 sec)
# INFO:tensorflow:global_step/sec: 2.15176
# INFO:tensorflow:loss = 0.022326427, step = 2700 (46.474 sec)
# INFO:tensorflow:global_step/sec: 2.14147
# INFO:tensorflow:loss = 0.027751671, step = 2800 (46.696 sec)
# INFO:tensorflow:global_step/sec: 2.11932
# INFO:tensorflow:loss = 0.03299634, step = 2900 (47.186 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3000...
# INFO:tensorflow:Saving checkpoints for 3000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T09:27:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.01250s
# INFO:tensorflow:Finished evaluation at 2025-01-06-09:33:50
# INFO:tensorflow:Saving dict for global step 3000: global_step = 3000, label/mean = -0.942441, loss = 0.0066675837, mae = 0.04505625, mse = 0.006668139, prediction/mean = -0.9119942, rho = 0.9693907
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: cp_dl_models_04012025_centralized/model.ckpt-3000
# INFO:tensorflow:global_step/sec: 0.247207
# INFO:tensorflow:loss = 0.03214006, step = 3000 (404.519 sec)
# INFO:tensorflow:global_step/sec: 2.14255
# INFO:tensorflow:loss = 0.024604559, step = 3100 (46.674 sec)
# INFO:tensorflow:global_step/sec: 2.11516
# INFO:tensorflow:loss = 0.018152371, step = 3200 (47.278 sec)
# INFO:tensorflow:global_step/sec: 2.10803
# INFO:tensorflow:loss = 0.029450988, step = 3300 (47.438 sec)
# INFO:tensorflow:global_step/sec: 2.1147
# INFO:tensorflow:loss = 0.01733117, step = 3400 (47.288 sec)
# INFO:tensorflow:global_step/sec: 2.11296
# INFO:tensorflow:loss = 0.04191966, step = 3500 (47.327 sec)
# INFO:tensorflow:global_step/sec: 2.10238
# INFO:tensorflow:loss = 0.034619883, step = 3600 (47.565 sec)
# INFO:tensorflow:global_step/sec: 2.11227
# INFO:tensorflow:loss = 0.01934805, step = 3700 (47.342 sec)
# INFO:tensorflow:global_step/sec: 2.10621
# INFO:tensorflow:loss = 0.044306546, step = 3800 (47.479 sec)
# INFO:tensorflow:global_step/sec: 2.08367
# INFO:tensorflow:loss = 0.012938942, step = 3900 (47.992 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4000...
# INFO:tensorflow:Saving checkpoints for 4000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T09:41:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 355.71670s
# INFO:tensorflow:Finished evaluation at 2025-01-06-09:47:44
# INFO:tensorflow:Saving dict for global step 4000: global_step = 4000, label/mean = -0.94243973, loss = 0.010169903, mae = 0.054635905, mse = 0.010171485, prediction/mean = -0.9136496, rho = 0.95664626
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: cp_dl_models_04012025_centralized/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 0.245913
# INFO:tensorflow:loss = 0.059948783, step = 4000 (406.647 sec)
# INFO:tensorflow:global_step/sec: 2.10897
# INFO:tensorflow:loss = 0.10038017, step = 4100 (47.417 sec)
# INFO:tensorflow:global_step/sec: 2.12736
# INFO:tensorflow:loss = 0.05329568, step = 4200 (47.006 sec)
# INFO:tensorflow:global_step/sec: 2.12847
# INFO:tensorflow:loss = 0.040589277, step = 4300 (46.982 sec)
# INFO:tensorflow:global_step/sec: 2.13809
# INFO:tensorflow:loss = 0.00976777, step = 4400 (46.781 sec)
# INFO:tensorflow:global_step/sec: 2.10712
# INFO:tensorflow:loss = 0.00933343, step = 4500 (47.447 sec)
# INFO:tensorflow:global_step/sec: 2.11453
# INFO:tensorflow:loss = 0.07388093, step = 4600 (47.292 sec)
# INFO:tensorflow:global_step/sec: 2.09542
# INFO:tensorflow:loss = 0.0331096, step = 4700 (47.723 sec)
# INFO:tensorflow:global_step/sec: 2.10391
# INFO:tensorflow:loss = 0.014718671, step = 4800 (47.531 sec)
# INFO:tensorflow:global_step/sec: 2.13181
# INFO:tensorflow:loss = 0.011326725, step = 4900 (46.908 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T09:55:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 358.23105s
# INFO:tensorflow:Finished evaluation at 2025-01-06-10:01:35
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, label/mean = -0.9424398, loss = 0.0058341785, mae = 0.035278562, mse = 0.005835267, prediction/mean = -0.9342203, rho = 0.96337223
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: cp_dl_models_04012025_centralized/model.ckpt-5000
# INFO:tensorflow:global_step/sec: 0.245759
# INFO:tensorflow:loss = 0.02912412, step = 5000 (406.903 sec)
# INFO:tensorflow:global_step/sec: 2.10796
# INFO:tensorflow:loss = 0.044753358, step = 5100 (47.439 sec)
# INFO:tensorflow:global_step/sec: 2.11216
# INFO:tensorflow:loss = 0.009591635, step = 5200 (47.345 sec)
# INFO:tensorflow:global_step/sec: 2.11128
# INFO:tensorflow:loss = 0.011407488, step = 5300 (47.364 sec)
# INFO:tensorflow:global_step/sec: 2.10795
# INFO:tensorflow:loss = 0.027691904, step = 5400 (47.440 sec)
# INFO:tensorflow:global_step/sec: 2.09829
# INFO:tensorflow:loss = 0.035501104, step = 5500 (47.658 sec)
# INFO:tensorflow:global_step/sec: 2.08101
# INFO:tensorflow:loss = 0.045153085, step = 5600 (48.054 sec)
# INFO:tensorflow:global_step/sec: 2.0773
# INFO:tensorflow:loss = 0.022833474, step = 5700 (48.139 sec)
# INFO:tensorflow:global_step/sec: 2.09401
# INFO:tensorflow:loss = 0.015802544, step = 5800 (47.756 sec)
# INFO:tensorflow:global_step/sec: 2.10518
# INFO:tensorflow:loss = 0.021747751, step = 5900 (47.502 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6000...
# INFO:tensorflow:Saving checkpoints for 6000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T10:09:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.11563s
# INFO:tensorflow:Finished evaluation at 2025-01-06-10:15:30
# INFO:tensorflow:Saving dict for global step 6000: global_step = 6000, label/mean = -0.9424396, loss = 0.008806479, mae = 0.042515237, mse = 0.00880452, prediction/mean = -0.92480606, rho = 0.9723614
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: cp_dl_models_04012025_centralized/model.ckpt-6000
# INFO:tensorflow:global_step/sec: 0.246434
# INFO:tensorflow:loss = 0.018469632, step = 6000 (405.788 sec)
# INFO:tensorflow:global_step/sec: 2.09792
# INFO:tensorflow:loss = 0.012853227, step = 6100 (47.666 sec)
# INFO:tensorflow:global_step/sec: 2.1008
# INFO:tensorflow:loss = 0.030971706, step = 6200 (47.601 sec)
# INFO:tensorflow:global_step/sec: 2.10396
# INFO:tensorflow:loss = 0.02920931, step = 6300 (47.529 sec)
# INFO:tensorflow:global_step/sec: 2.11572
# INFO:tensorflow:loss = 0.008942144, step = 6400 (47.265 sec)
# INFO:tensorflow:global_step/sec: 2.10546
# INFO:tensorflow:loss = 0.017748088, step = 6500 (47.496 sec)
# INFO:tensorflow:global_step/sec: 2.10471
# INFO:tensorflow:loss = 0.011162662, step = 6600 (47.513 sec)
# INFO:tensorflow:global_step/sec: 2.08714
# INFO:tensorflow:loss = 0.011668422, step = 6700 (47.912 sec)
# INFO:tensorflow:global_step/sec: 2.09613
# INFO:tensorflow:loss = 0.021879336, step = 6800 (47.707 sec)
# INFO:tensorflow:global_step/sec: 2.09833
# INFO:tensorflow:loss = 0.020043656, step = 6900 (47.657 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 7000...
# INFO:tensorflow:Saving checkpoints for 7000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 7000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T10:23:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 357.74070s
# INFO:tensorflow:Finished evaluation at 2025-01-06-10:29:25
# INFO:tensorflow:Saving dict for global step 7000: global_step = 7000, label/mean = -0.94244045, loss = 0.002523338, mae = 0.025334204, mse = 0.0025237598, prediction/mean = -0.94487315, rho = 0.9839067
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: cp_dl_models_04012025_centralized/model.ckpt-7000
# INFO:tensorflow:global_step/sec: 0.246021
# INFO:tensorflow:loss = 0.032445453, step = 7000 (406.469 sec)
# INFO:tensorflow:global_step/sec: 2.06832
# INFO:tensorflow:loss = 0.023170209, step = 7100 (48.349 sec)
# INFO:tensorflow:global_step/sec: 2.06192
# INFO:tensorflow:loss = 0.035656415, step = 7200 (48.499 sec)
# INFO:tensorflow:global_step/sec: 2.04999
# INFO:tensorflow:loss = 0.043138154, step = 7300 (48.780 sec)
# INFO:tensorflow:global_step/sec: 2.0405
# INFO:tensorflow:loss = 0.035591178, step = 7400 (49.008 sec)
# INFO:tensorflow:global_step/sec: 2.0484
# INFO:tensorflow:loss = 0.02295204, step = 7500 (48.818 sec)
# INFO:tensorflow:global_step/sec: 2.06559
# INFO:tensorflow:loss = 0.024196923, step = 7600 (48.413 sec)
# INFO:tensorflow:global_step/sec: 2.08191
# INFO:tensorflow:loss = 0.062222518, step = 7700 (48.032 sec)
# INFO:tensorflow:global_step/sec: 2.11385
# INFO:tensorflow:loss = 0.018030701, step = 7800 (47.307 sec)
# INFO:tensorflow:global_step/sec: 2.10952
# INFO:tensorflow:loss = 0.03962291, step = 7900 (47.404 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8000...
# INFO:tensorflow:Saving checkpoints for 8000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T10:37:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.82021s
# INFO:tensorflow:Finished evaluation at 2025-01-06-10:43:25
# INFO:tensorflow:Saving dict for global step 8000: global_step = 8000, label/mean = -0.94244003, loss = 0.00892729, mae = 0.07852021, mse = 0.008927765, prediction/mean = -0.87135345, rho = 0.9832759
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: cp_dl_models_04012025_centralized/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 0.24681
# INFO:tensorflow:loss = 0.013465847, step = 8000 (405.170 sec)
# INFO:tensorflow:global_step/sec: 2.12846
# INFO:tensorflow:loss = 0.022859985, step = 8100 (46.982 sec)
# INFO:tensorflow:global_step/sec: 2.13161
# INFO:tensorflow:loss = 0.04883811, step = 8200 (46.927 sec)
# INFO:tensorflow:global_step/sec: 2.13664
# INFO:tensorflow:loss = 0.028138727, step = 8300 (46.788 sec)
# INFO:tensorflow:global_step/sec: 2.12627
# INFO:tensorflow:loss = 0.017867941, step = 8400 (47.030 sec)
# INFO:tensorflow:global_step/sec: 2.13351
# INFO:tensorflow:loss = 0.019700715, step = 8500 (46.871 sec)
# INFO:tensorflow:global_step/sec: 2.15637
# INFO:tensorflow:loss = 0.022538038, step = 8600 (46.375 sec)
# INFO:tensorflow:global_step/sec: 2.14754
# INFO:tensorflow:loss = 0.01295244, step = 8700 (46.565 sec)
# INFO:tensorflow:global_step/sec: 2.14375
# INFO:tensorflow:loss = 0.014554318, step = 8800 (46.647 sec)
# INFO:tensorflow:global_step/sec: 2.14618
# INFO:tensorflow:loss = 0.04570481, step = 8900 (46.594 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 9000...
# INFO:tensorflow:Saving checkpoints for 9000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 9000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T10:52:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.47404s
# INFO:tensorflow:Finished evaluation at 2025-01-06-10:57:59
# INFO:tensorflow:Saving dict for global step 9000: global_step = 9000, label/mean = -0.9424395, loss = 0.0020926988, mae = 0.027456013, mse = 0.0020926078, prediction/mean = -0.94609475, rho = 0.9866431
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: cp_dl_models_04012025_centralized/model.ckpt-9000
# INFO:tensorflow:global_step/sec: 0.220619
# INFO:tensorflow:loss = 0.016160702, step = 9000 (453.270 sec)
# INFO:tensorflow:global_step/sec: 2.142
# INFO:tensorflow:loss = 0.021255137, step = 9100 (46.686 sec)
# INFO:tensorflow:global_step/sec: 2.1591
# INFO:tensorflow:loss = 0.013480687, step = 9200 (46.315 sec)
# INFO:tensorflow:global_step/sec: 2.1312
# INFO:tensorflow:loss = 0.049695592, step = 9300 (46.923 sec)
# INFO:tensorflow:global_step/sec: 2.12224
# INFO:tensorflow:loss = 0.010797522, step = 9400 (47.119 sec)
# INFO:tensorflow:global_step/sec: 2.12161
# INFO:tensorflow:loss = 0.0127701545, step = 9500 (47.134 sec)
# INFO:tensorflow:global_step/sec: 2.14034
# INFO:tensorflow:loss = 0.019794533, step = 9600 (46.721 sec)
# INFO:tensorflow:global_step/sec: 2.13708
# INFO:tensorflow:loss = 0.04197713, step = 9700 (46.793 sec)
# INFO:tensorflow:global_step/sec: 2.15108
# INFO:tensorflow:loss = 0.015261421, step = 9800 (46.489 sec)
# INFO:tensorflow:global_step/sec: 2.14298
# INFO:tensorflow:loss = 0.010417734, step = 9900 (46.664 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T11:05:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 355.39054s
# INFO:tensorflow:Finished evaluation at 2025-01-06-11:11:42
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, label/mean = -0.9424399, loss = 0.004381072, mae = 0.043381985, mse = 0.0043815225, prediction/mean = -0.9295583, rho = 0.97627586
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: cp_dl_models_04012025_centralized/model.ckpt-10000
# INFO:tensorflow:global_step/sec: 0.24815
# INFO:tensorflow:loss = 0.015009971, step = 10000 (402.982 sec)
# INFO:tensorflow:global_step/sec: 2.15097
# INFO:tensorflow:loss = 0.07532061, step = 10100 (46.491 sec)
# INFO:tensorflow:global_step/sec: 2.1501
# INFO:tensorflow:loss = 0.037762832, step = 10200 (46.509 sec)
# INFO:tensorflow:global_step/sec: 2.1603
# INFO:tensorflow:loss = 0.028566778, step = 10300 (46.290 sec)
# INFO:tensorflow:global_step/sec: 2.13869
# INFO:tensorflow:loss = 0.06516026, step = 10400 (46.757 sec)
# INFO:tensorflow:global_step/sec: 2.13967
# INFO:tensorflow:loss = 0.009416828, step = 10500 (46.737 sec)
# INFO:tensorflow:global_step/sec: 2.13528
# INFO:tensorflow:loss = 0.017230779, step = 10600 (46.832 sec)
# INFO:tensorflow:global_step/sec: 2.14851
# INFO:tensorflow:loss = 0.1163665, step = 10700 (46.544 sec)
# INFO:tensorflow:global_step/sec: 2.15224
# INFO:tensorflow:loss = 0.03226232, step = 10800 (46.463 sec)
# INFO:tensorflow:global_step/sec: 2.15635
# INFO:tensorflow:loss = 0.012190306, step = 10900 (46.375 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 11000...
# INFO:tensorflow:Saving checkpoints for 11000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 11000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T11:19:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 358.24656s
# INFO:tensorflow:Finished evaluation at 2025-01-06-11:25:27
# INFO:tensorflow:Saving dict for global step 11000: global_step = 11000, label/mean = -0.9424407, loss = 0.005270181, mae = 0.030076787, mse = 0.0052698683, prediction/mean = -0.9327765, rho = 0.9838553
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: cp_dl_models_04012025_centralized/model.ckpt-11000
# INFO:tensorflow:global_step/sec: 0.246594
# INFO:tensorflow:loss = 0.016573565, step = 11000 (405.526 sec)
# INFO:tensorflow:global_step/sec: 2.15702
# INFO:tensorflow:loss = 0.040355492, step = 11100 (46.360 sec)
# INFO:tensorflow:global_step/sec: 2.16184
# INFO:tensorflow:loss = 0.009322987, step = 11200 (46.257 sec)
# INFO:tensorflow:global_step/sec: 2.17666
# INFO:tensorflow:loss = 0.025377369, step = 11300 (45.942 sec)
# INFO:tensorflow:global_step/sec: 2.1517
# INFO:tensorflow:loss = 0.0320038, step = 11400 (46.475 sec)
# INFO:tensorflow:global_step/sec: 2.13437
# INFO:tensorflow:loss = 0.01917199, step = 11500 (46.852 sec)
# INFO:tensorflow:global_step/sec: 2.14704
# INFO:tensorflow:loss = 0.012858868, step = 11600 (46.576 sec)
# INFO:tensorflow:global_step/sec: 2.13448
# INFO:tensorflow:loss = 0.015457549, step = 11700 (46.850 sec)
# INFO:tensorflow:global_step/sec: 2.14396
# INFO:tensorflow:loss = 0.040029727, step = 11800 (46.643 sec)
# INFO:tensorflow:global_step/sec: 2.1265
# INFO:tensorflow:loss = 0.019628296, step = 11900 (47.026 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 12000...
# INFO:tensorflow:Saving checkpoints for 12000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 12000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T11:33:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 354.76990s
# INFO:tensorflow:Finished evaluation at 2025-01-06-11:39:09
# INFO:tensorflow:Saving dict for global step 12000: global_step = 12000, label/mean = -0.94244033, loss = 0.0035770254, mae = 0.03834964, mse = 0.003577391, prediction/mean = -0.91257787, rho = 0.98989975
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: cp_dl_models_04012025_centralized/model.ckpt-12000
# INFO:tensorflow:global_step/sec: 0.248034
# INFO:tensorflow:loss = 0.03127324, step = 12000 (403.171 sec)
# INFO:tensorflow:global_step/sec: 2.1172
# INFO:tensorflow:loss = 0.019542946, step = 12100 (47.232 sec)
# INFO:tensorflow:global_step/sec: 2.11205
# INFO:tensorflow:loss = 0.04149675, step = 12200 (47.348 sec)
# INFO:tensorflow:global_step/sec: 2.11411
# INFO:tensorflow:loss = 0.04114706, step = 12300 (47.301 sec)
# INFO:tensorflow:global_step/sec: 2.11371
# INFO:tensorflow:loss = 0.01592118, step = 12400 (47.310 sec)
# INFO:tensorflow:global_step/sec: 2.11562
# INFO:tensorflow:loss = 0.016067049, step = 12500 (47.268 sec)
# INFO:tensorflow:global_step/sec: 2.11196
# INFO:tensorflow:loss = 0.023903694, step = 12600 (47.349 sec)
# INFO:tensorflow:global_step/sec: 2.11482
# INFO:tensorflow:loss = 0.020307219, step = 12700 (47.286 sec)
# INFO:tensorflow:global_step/sec: 2.11991
# INFO:tensorflow:loss = 0.025541635, step = 12800 (47.171 sec)
# INFO:tensorflow:global_step/sec: 2.11772
# INFO:tensorflow:loss = 0.035413958, step = 12900 (47.221 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 13000...
# INFO:tensorflow:Saving checkpoints for 13000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 13000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T11:47:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.25047s
# INFO:tensorflow:Finished evaluation at 2025-01-06-11:53:00
# INFO:tensorflow:Saving dict for global step 13000: global_step = 13000, label/mean = -0.9424398, loss = 0.002469287, mae = 0.028427307, mse = 0.0024694987, prediction/mean = -0.9252817, rho = 0.9859111
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13000: cp_dl_models_04012025_centralized/model.ckpt-13000
# INFO:tensorflow:global_step/sec: 0.24655
# INFO:tensorflow:loss = 0.010607276, step = 13000 (405.597 sec)
# INFO:tensorflow:global_step/sec: 2.09274
# INFO:tensorflow:loss = 0.027291, step = 13100 (47.785 sec)
# INFO:tensorflow:global_step/sec: 2.10531
# INFO:tensorflow:loss = 0.028830456, step = 13200 (47.498 sec)
# INFO:tensorflow:global_step/sec: 2.09827
# INFO:tensorflow:loss = 0.021879727, step = 13300 (47.659 sec)
# INFO:tensorflow:global_step/sec: 2.08453
# INFO:tensorflow:loss = 0.027353829, step = 13400 (47.972 sec)
# INFO:tensorflow:global_step/sec: 2.08703
# INFO:tensorflow:loss = 0.04609536, step = 13500 (47.915 sec)
# INFO:tensorflow:global_step/sec: 2.10346
# INFO:tensorflow:loss = 0.012687415, step = 13600 (47.540 sec)
# INFO:tensorflow:global_step/sec: 2.09607
# INFO:tensorflow:loss = 0.041067384, step = 13700 (47.709 sec)
# INFO:tensorflow:global_step/sec: 2.08887
# INFO:tensorflow:loss = 0.02318598, step = 13800 (47.872 sec)
# INFO:tensorflow:global_step/sec: 2.07872
# INFO:tensorflow:loss = 0.042813405, step = 13900 (48.107 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 14000...
# INFO:tensorflow:Saving checkpoints for 14000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 14000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T12:00:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 801.70079s
# INFO:tensorflow:Finished evaluation at 2025-01-06-12:14:21
# INFO:tensorflow:Saving dict for global step 14000: global_step = 14000, label/mean = -0.9424404, loss = 0.0024861393, mae = 0.025282415, mse = 0.0024864262, prediction/mean = -0.9236889, rho = 0.9871897
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: cp_dl_models_04012025_centralized/model.ckpt-14000
# INFO:tensorflow:global_step/sec: 0.117604
# INFO:tensorflow:loss = 0.012702407, step = 14000 (850.307 sec)
# INFO:tensorflow:global_step/sec: 2.16921
# INFO:tensorflow:loss = 0.03389925, step = 14100 (46.100 sec)
# INFO:tensorflow:global_step/sec: 2.1675
# INFO:tensorflow:loss = 0.010899324, step = 14200 (46.136 sec)
# INFO:tensorflow:global_step/sec: 2.16804
# INFO:tensorflow:loss = 0.012734017, step = 14300 (46.125 sec)
# INFO:tensorflow:global_step/sec: 2.15123
# INFO:tensorflow:loss = 0.024379754, step = 14400 (46.484 sec)
# INFO:tensorflow:global_step/sec: 2.1401
# INFO:tensorflow:loss = 0.013469945, step = 14500 (46.727 sec)
# INFO:tensorflow:global_step/sec: 2.12546
# INFO:tensorflow:loss = 0.014191572, step = 14600 (47.048 sec)
# INFO:tensorflow:global_step/sec: 2.11599
# INFO:tensorflow:loss = 0.026213337, step = 14700 (47.260 sec)
# INFO:tensorflow:global_step/sec: 2.11854
# INFO:tensorflow:loss = 0.0047467384, step = 14800 (47.202 sec)
# INFO:tensorflow:global_step/sec: 2.11269
# INFO:tensorflow:loss = 0.015936883, step = 14900 (47.333 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 15000...
# INFO:tensorflow:Saving checkpoints for 15000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 15000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T12:22:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 355.77136s
# INFO:tensorflow:Finished evaluation at 2025-01-06-12:28:05
# INFO:tensorflow:Saving dict for global step 15000: global_step = 15000, label/mean = -0.9424407, loss = 0.0022204288, mae = 0.034993004, mse = 0.0022206437, prediction/mean = -0.965898, rho = 0.98921466
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: cp_dl_models_04012025_centralized/model.ckpt-15000
# INFO:tensorflow:global_step/sec: 0.247331
# INFO:tensorflow:loss = 0.02174275, step = 15000 (404.316 sec)
# INFO:tensorflow:global_step/sec: 2.10311
# INFO:tensorflow:loss = 0.026550487, step = 15100 (47.549 sec)
# INFO:tensorflow:global_step/sec: 2.12727
# INFO:tensorflow:loss = 0.015284524, step = 15200 (47.008 sec)
# INFO:tensorflow:global_step/sec: 2.15505
# INFO:tensorflow:loss = 0.025948372, step = 15300 (46.402 sec)
# INFO:tensorflow:global_step/sec: 2.11684
# INFO:tensorflow:loss = 0.025008831, step = 15400 (47.241 sec)
# INFO:tensorflow:global_step/sec: 2.12138
# INFO:tensorflow:loss = 0.012740899, step = 15500 (47.139 sec)
# INFO:tensorflow:global_step/sec: 2.15262
# INFO:tensorflow:loss = 0.009284957, step = 15600 (46.456 sec)
# INFO:tensorflow:global_step/sec: 2.15022
# INFO:tensorflow:loss = 0.021586364, step = 15700 (46.506 sec)
# INFO:tensorflow:global_step/sec: 2.1301
# INFO:tensorflow:loss = 0.012074486, step = 15800 (46.946 sec)
# INFO:tensorflow:global_step/sec: 2.11954
# INFO:tensorflow:loss = 0.014420468, step = 15900 (47.180 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 16000...
# INFO:tensorflow:Saving checkpoints for 16000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 16000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T12:35:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 358.54558s
# INFO:tensorflow:Finished evaluation at 2025-01-06-12:41:54
# INFO:tensorflow:Saving dict for global step 16000: global_step = 16000, label/mean = -0.94244087, loss = 0.004349665, mae = 0.038187455, mse = 0.004350158, prediction/mean = -0.9142778, rho = 0.98722404
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: cp_dl_models_04012025_centralized/model.ckpt-16000
# INFO:tensorflow:global_step/sec: 0.246032
# INFO:tensorflow:loss = 0.02794075, step = 16000 (406.450 sec)
# INFO:tensorflow:global_step/sec: 2.08538
# INFO:tensorflow:loss = 0.041128088, step = 16100 (47.953 sec)
# INFO:tensorflow:global_step/sec: 2.08402
# INFO:tensorflow:loss = 0.013150282, step = 16200 (47.984 sec)
# INFO:tensorflow:global_step/sec: 2.07897
# INFO:tensorflow:loss = 0.00769167, step = 16300 (48.101 sec)
# INFO:tensorflow:global_step/sec: 2.08855
# INFO:tensorflow:loss = 0.007036361, step = 16400 (47.880 sec)
# INFO:tensorflow:global_step/sec: 2.05419
# INFO:tensorflow:loss = 0.03406482, step = 16500 (48.681 sec)
# INFO:tensorflow:global_step/sec: 2.05438
# INFO:tensorflow:loss = 0.009700098, step = 16600 (48.677 sec)
# INFO:tensorflow:global_step/sec: 2.0667
# INFO:tensorflow:loss = 0.013697475, step = 16700 (48.386 sec)
# INFO:tensorflow:global_step/sec: 2.09918
# INFO:tensorflow:loss = 0.013254341, step = 16800 (47.638 sec)
# INFO:tensorflow:global_step/sec: 2.07733
# INFO:tensorflow:loss = 0.047723833, step = 16900 (48.138 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 17000...
# INFO:tensorflow:Saving checkpoints for 17000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 17000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T12:49:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 352.37785s
# INFO:tensorflow:Finished evaluation at 2025-01-06-12:55:49
# INFO:tensorflow:Saving dict for global step 17000: global_step = 17000, label/mean = -0.94243985, loss = 0.0026158174, mae = 0.027127901, mse = 0.002616262, prediction/mean = -0.94566625, rho = 0.9828091
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17000: cp_dl_models_04012025_centralized/model.ckpt-17000
# INFO:tensorflow:global_step/sec: 0.249066
# INFO:tensorflow:loss = 0.07669481, step = 17000 (401.501 sec)
# INFO:tensorflow:global_step/sec: 2.0797
# INFO:tensorflow:loss = 0.006241713, step = 17100 (48.084 sec)
# INFO:tensorflow:global_step/sec: 2.09314
# INFO:tensorflow:loss = 0.014521183, step = 17200 (47.775 sec)
# INFO:tensorflow:global_step/sec: 2.10095
# INFO:tensorflow:loss = 0.09522455, step = 17300 (47.598 sec)
# INFO:tensorflow:global_step/sec: 2.10457
# INFO:tensorflow:loss = 0.030080132, step = 17400 (47.515 sec)
# INFO:tensorflow:global_step/sec: 2.1047
# INFO:tensorflow:loss = 0.011037929, step = 17500 (47.513 sec)
# INFO:tensorflow:global_step/sec: 2.11339
# INFO:tensorflow:loss = 0.02202581, step = 17600 (47.317 sec)
# INFO:tensorflow:global_step/sec: 2.10691
# INFO:tensorflow:loss = 0.011095044, step = 17700 (47.463 sec)
# INFO:tensorflow:global_step/sec: 2.07195
# INFO:tensorflow:loss = 0.026990613, step = 17800 (48.263 sec)
# INFO:tensorflow:global_step/sec: 2.04328
# INFO:tensorflow:loss = 0.011857587, step = 17900 (48.942 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 18000...
# INFO:tensorflow:Saving checkpoints for 18000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 18000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T13:03:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 354.68226s
# INFO:tensorflow:Finished evaluation at 2025-01-06-13:09:44
# INFO:tensorflow:Saving dict for global step 18000: global_step = 18000, label/mean = -0.9424396, loss = 0.0025746694, mae = 0.03493509, mse = 0.0025727402, prediction/mean = -0.91776633, rho = 0.9906589
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: cp_dl_models_04012025_centralized/model.ckpt-18000
# INFO:tensorflow:global_step/sec: 0.247298
# INFO:tensorflow:loss = 0.018697618, step = 18000 (404.370 sec)
# INFO:tensorflow:global_step/sec: 2.07858
# INFO:tensorflow:loss = 0.010827779, step = 18100 (48.110 sec)
# INFO:tensorflow:global_step/sec: 2.10423
# INFO:tensorflow:loss = 0.024433412, step = 18200 (47.524 sec)
# INFO:tensorflow:global_step/sec: 2.11354
# INFO:tensorflow:loss = 0.020906143, step = 18300 (47.313 sec)
# INFO:tensorflow:global_step/sec: 2.09817
# INFO:tensorflow:loss = 0.044119436, step = 18400 (47.661 sec)
# INFO:tensorflow:global_step/sec: 2.06907
# INFO:tensorflow:loss = 0.04273317, step = 18500 (48.331 sec)
# INFO:tensorflow:global_step/sec: 2.10717
# INFO:tensorflow:loss = 0.055448882, step = 18600 (47.457 sec)
# INFO:tensorflow:global_step/sec: 2.15071
# INFO:tensorflow:loss = 0.01894777, step = 18700 (46.497 sec)
# INFO:tensorflow:global_step/sec: 2.16518
# INFO:tensorflow:loss = 0.029806081, step = 18800 (46.185 sec)
# INFO:tensorflow:global_step/sec: 2.1497
# INFO:tensorflow:loss = 0.005218371, step = 18900 (46.519 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 19000...
# INFO:tensorflow:Saving checkpoints for 19000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 19000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T13:17:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-19000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 354.75243s
# INFO:tensorflow:Finished evaluation at 2025-01-06-13:23:32
# INFO:tensorflow:Saving dict for global step 19000: global_step = 19000, label/mean = -0.9424407, loss = 0.0029328617, mae = 0.028771952, mse = 0.0029332303, prediction/mean = -0.93284845, rho = 0.9892235
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19000: cp_dl_models_04012025_centralized/model.ckpt-19000
# INFO:tensorflow:global_step/sec: 0.248677
# INFO:tensorflow:loss = 0.016753925, step = 19000 (402.128 sec)
# INFO:tensorflow:global_step/sec: 2.18267
# INFO:tensorflow:loss = 0.028151033, step = 19100 (45.816 sec)
# INFO:tensorflow:global_step/sec: 2.16929
# INFO:tensorflow:loss = 0.017865205, step = 19200 (46.097 sec)
# INFO:tensorflow:global_step/sec: 2.18276
# INFO:tensorflow:loss = 0.021950504, step = 19300 (45.814 sec)
# INFO:tensorflow:global_step/sec: 2.14142
# INFO:tensorflow:loss = 0.021616714, step = 19400 (46.698 sec)
# INFO:tensorflow:global_step/sec: 2.1688
# INFO:tensorflow:loss = 0.021553911, step = 19500 (46.109 sec)
# INFO:tensorflow:global_step/sec: 2.1773
# INFO:tensorflow:loss = 0.012309188, step = 19600 (45.928 sec)
# INFO:tensorflow:global_step/sec: 2.16188
# INFO:tensorflow:loss = 0.08148537, step = 19700 (46.256 sec)
# INFO:tensorflow:global_step/sec: 2.16391
# INFO:tensorflow:loss = 0.036066428, step = 19800 (46.213 sec)
# INFO:tensorflow:global_step/sec: 2.16291
# INFO:tensorflow:loss = 0.024029134, step = 19900 (46.234 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20000...
# INFO:tensorflow:Saving checkpoints for 20000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T13:31:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 357.01027s
# INFO:tensorflow:Finished evaluation at 2025-01-06-13:37:23
# INFO:tensorflow:Saving dict for global step 20000: global_step = 20000, label/mean = -0.9424401, loss = 0.0038657484, mae = 0.04868062, mse = 0.0038659293, prediction/mean = -0.9009085, rho = 0.99118185
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: cp_dl_models_04012025_centralized/model.ckpt-20000
# INFO:tensorflow:global_step/sec: 0.240207
# INFO:tensorflow:loss = 0.043717436, step = 20000 (416.308 sec)
# INFO:tensorflow:global_step/sec: 2.1509
# INFO:tensorflow:loss = 0.030805556, step = 20100 (46.492 sec)
# INFO:tensorflow:global_step/sec: 2.15739
# INFO:tensorflow:loss = 0.013221693, step = 20200 (46.352 sec)
# INFO:tensorflow:global_step/sec: 2.1445
# INFO:tensorflow:loss = 0.0687314, step = 20300 (46.631 sec)
# INFO:tensorflow:global_step/sec: 2.14715
# INFO:tensorflow:loss = 0.025543805, step = 20400 (46.574 sec)
# INFO:tensorflow:global_step/sec: 2.13963
# INFO:tensorflow:loss = 0.025206285, step = 20500 (46.737 sec)
# INFO:tensorflow:global_step/sec: 2.15163
# INFO:tensorflow:loss = 0.011353873, step = 20600 (46.477 sec)
# INFO:tensorflow:global_step/sec: 2.15311
# INFO:tensorflow:loss = 0.015332567, step = 20700 (46.444 sec)
# INFO:tensorflow:global_step/sec: 2.14798
# INFO:tensorflow:loss = 0.02745607, step = 20800 (46.556 sec)
# INFO:tensorflow:global_step/sec: 2.15422
# INFO:tensorflow:loss = 0.024828335, step = 20900 (46.420 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 21000...
# INFO:tensorflow:Saving checkpoints for 21000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 21000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T13:45:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-21000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 357.62657s
# INFO:tensorflow:Finished evaluation at 2025-01-06-13:51:07
# INFO:tensorflow:Saving dict for global step 21000: global_step = 21000, label/mean = -0.9424383, loss = 0.0038197674, mae = 0.029880805, mse = 0.0038202493, prediction/mean = -0.92096657, rho = 0.9816527
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 21000: cp_dl_models_04012025_centralized/model.ckpt-21000
# INFO:tensorflow:global_step/sec: 0.24714
# INFO:tensorflow:loss = 0.0071467324, step = 21000 (404.629 sec)
# INFO:tensorflow:global_step/sec: 2.22085
# INFO:tensorflow:loss = 0.023298, step = 21100 (45.028 sec)
# INFO:tensorflow:global_step/sec: 2.20135
# INFO:tensorflow:loss = 0.022015076, step = 21200 (45.427 sec)
# INFO:tensorflow:global_step/sec: 2.19629
# INFO:tensorflow:loss = 0.012291521, step = 21300 (45.531 sec)
# INFO:tensorflow:global_step/sec: 2.16692
# INFO:tensorflow:loss = 0.0137675, step = 21400 (46.148 sec)
# INFO:tensorflow:global_step/sec: 2.16855
# INFO:tensorflow:loss = 0.025496658, step = 21500 (46.114 sec)
# INFO:tensorflow:global_step/sec: 2.17305
# INFO:tensorflow:loss = 0.025313597, step = 21600 (46.018 sec)
# INFO:tensorflow:global_step/sec: 2.14913
# INFO:tensorflow:loss = 0.017103836, step = 21700 (46.531 sec)
# INFO:tensorflow:global_step/sec: 2.14846
# INFO:tensorflow:loss = 0.050387908, step = 21800 (46.545 sec)
# INFO:tensorflow:global_step/sec: 2.15877
# INFO:tensorflow:loss = 0.014713092, step = 21900 (46.322 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 22000...
# INFO:tensorflow:Saving checkpoints for 22000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 22000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T13:58:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-22000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 353.92724s
# INFO:tensorflow:Finished evaluation at 2025-01-06-14:04:42
# INFO:tensorflow:Saving dict for global step 22000: global_step = 22000, label/mean = -0.9424384, loss = 0.003555762, mae = 0.048390538, mse = 0.003555942, prediction/mean = -0.89734876, rho = 0.99097717
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 22000: cp_dl_models_04012025_centralized/model.ckpt-22000
# INFO:tensorflow:global_step/sec: 0.249062
# INFO:tensorflow:loss = 0.015945934, step = 22000 (401.507 sec)
# INFO:tensorflow:global_step/sec: 2.17173
# INFO:tensorflow:loss = 0.030381313, step = 22100 (46.046 sec)
# INFO:tensorflow:global_step/sec: 2.16924
# INFO:tensorflow:loss = 0.03646874, step = 22200 (46.100 sec)
# INFO:tensorflow:global_step/sec: 2.12473
# INFO:tensorflow:loss = 0.014129569, step = 22300 (47.064 sec)
# INFO:tensorflow:global_step/sec: 2.13301
# INFO:tensorflow:loss = 0.025243739, step = 22400 (46.882 sec)
# INFO:tensorflow:global_step/sec: 2.14753
# INFO:tensorflow:loss = 0.00398202, step = 22500 (46.565 sec)
# INFO:tensorflow:global_step/sec: 2.14676
# INFO:tensorflow:loss = 0.04468395, step = 22600 (46.582 sec)
# INFO:tensorflow:global_step/sec: 2.15195
# INFO:tensorflow:loss = 0.04175394, step = 22700 (46.469 sec)
# INFO:tensorflow:global_step/sec: 2.13123
# INFO:tensorflow:loss = 0.08310552, step = 22800 (46.921 sec)
# INFO:tensorflow:global_step/sec: 2.1207
# INFO:tensorflow:loss = 0.008084085, step = 22900 (47.154 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 23000...
# ...
# INFO:tensorflow:global_step/sec: 2.11688
# INFO:tensorflow:loss = 0.03457665, step = 42600 (47.239 sec)
# INFO:tensorflow:global_step/sec: 2.09955
# INFO:tensorflow:loss = 0.015268969, step = 42700 (47.629 sec)
# INFO:tensorflow:global_step/sec: 2.09386
# INFO:tensorflow:loss = 0.0564281, step = 42800 (47.759 sec)
# INFO:tensorflow:global_step/sec: 2.10097
# INFO:tensorflow:loss = 0.00835529, step = 42900 (47.597 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 43000...
# INFO:tensorflow:Saving checkpoints for 43000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 43000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T18:49:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-43000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 357.05942s
# INFO:tensorflow:Finished evaluation at 2025-01-06-18:55:37
# INFO:tensorflow:Saving dict for global step 43000: global_step = 43000, label/mean = -0.942439, loss = 0.0022257832, mae = 0.025537295, mse = 0.0022260372, prediction/mean = -0.9196368, rho = 0.9904153
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 43000: cp_dl_models_04012025_centralized/model.ckpt-43000
# INFO:tensorflow:global_step/sec: 0.246535
# INFO:tensorflow:loss = 0.014386389, step = 43000 (405.622 sec)
# INFO:tensorflow:global_step/sec: 2.09343
# INFO:tensorflow:loss = 0.01147836, step = 43100 (47.769 sec)
# INFO:tensorflow:global_step/sec: 2.12222
# INFO:tensorflow:loss = 0.0109051345, step = 43200 (47.121 sec)
# INFO:tensorflow:global_step/sec: 2.13147
# INFO:tensorflow:loss = 0.01269275, step = 43300 (46.916 sec)
# INFO:tensorflow:global_step/sec: 2.11859
# INFO:tensorflow:loss = 0.03879547, step = 43400 (47.202 sec)
# INFO:tensorflow:global_step/sec: 2.15327
# INFO:tensorflow:loss = 0.044601534, step = 43500 (46.441 sec)
# INFO:tensorflow:global_step/sec: 2.1384
# INFO:tensorflow:loss = 0.018097, step = 43600 (46.764 sec)
# INFO:tensorflow:global_step/sec: 2.1226
# INFO:tensorflow:loss = 0.0052875574, step = 43700 (47.111 sec)
# INFO:tensorflow:global_step/sec: 2.12548
# INFO:tensorflow:loss = 0.04814666, step = 43800 (47.048 sec)
# INFO:tensorflow:global_step/sec: 2.09854
# INFO:tensorflow:loss = 0.020309288, step = 43900 (47.653 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 44000...
# INFO:tensorflow:Saving checkpoints for 44000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 44000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T19:04:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.65722s
# INFO:tensorflow:Finished evaluation at 2025-01-06-19:10:36
# INFO:tensorflow:Saving dict for global step 44000: global_step = 44000, label/mean = -0.9424402, loss = 0.0014761746, mae = 0.022250472, mse = 0.0014762816, prediction/mean = -0.9289828, rho = 0.9925183
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: cp_dl_models_04012025_centralized/model.ckpt-44000
# INFO:tensorflow:global_step/sec: 0.210657
# INFO:tensorflow:loss = 0.019019987, step = 44000 (474.706 sec)
# INFO:tensorflow:global_step/sec: 2.0744
# INFO:tensorflow:loss = 0.022228949, step = 44100 (48.207 sec)
# INFO:tensorflow:global_step/sec: 2.09783
# INFO:tensorflow:loss = 0.024936236, step = 44200 (47.669 sec)
# INFO:tensorflow:global_step/sec: 2.08242
# INFO:tensorflow:loss = 0.012516525, step = 44300 (48.021 sec)
# INFO:tensorflow:global_step/sec: 2.08865
# INFO:tensorflow:loss = 0.016385065, step = 44400 (47.878 sec)
# INFO:tensorflow:global_step/sec: 2.09734
# INFO:tensorflow:loss = 0.02375579, step = 44500 (47.679 sec)
# INFO:tensorflow:global_step/sec: 2.12003
# INFO:tensorflow:loss = 0.08044578, step = 44600 (47.170 sec)
# INFO:tensorflow:global_step/sec: 2.10544
# INFO:tensorflow:loss = 0.017457236, step = 44700 (47.495 sec)
# INFO:tensorflow:global_step/sec: 2.10086
# INFO:tensorflow:loss = 0.033518214, step = 44800 (47.600 sec)
# INFO:tensorflow:global_step/sec: 2.13468
# INFO:tensorflow:loss = 0.02564959, step = 44900 (46.845 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 45000...
# INFO:tensorflow:Saving checkpoints for 45000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 45000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T19:18:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-45000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 355.40466s
# INFO:tensorflow:Finished evaluation at 2025-01-06-19:24:28
# INFO:tensorflow:Saving dict for global step 45000: global_step = 45000, label/mean = -0.94244033, loss = 0.005123557, mae = 0.05494353, mse = 0.005123809, prediction/mean = -0.89635426, rho = 0.9878957
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45000: cp_dl_models_04012025_centralized/model.ckpt-45000
# INFO:tensorflow:global_step/sec: 0.247648
# INFO:tensorflow:loss = 0.035664067, step = 45000 (403.799 sec)
# INFO:tensorflow:global_step/sec: 2.11063
# INFO:tensorflow:loss = 0.013875084, step = 45100 (47.380 sec)
# INFO:tensorflow:global_step/sec: 2.12099
# INFO:tensorflow:loss = 0.044328075, step = 45200 (47.147 sec)
# INFO:tensorflow:global_step/sec: 2.11729
# INFO:tensorflow:loss = 0.04480843, step = 45300 (47.230 sec)
# INFO:tensorflow:global_step/sec: 2.13685
# INFO:tensorflow:loss = 0.020338735, step = 45400 (46.798 sec)
# INFO:tensorflow:global_step/sec: 2.14113
# INFO:tensorflow:loss = 0.02787287, step = 45500 (46.704 sec)
# INFO:tensorflow:global_step/sec: 2.15562
# INFO:tensorflow:loss = 0.022840356, step = 45600 (46.391 sec)
# INFO:tensorflow:global_step/sec: 2.16305
# INFO:tensorflow:loss = 0.028575422, step = 45700 (46.230 sec)
# INFO:tensorflow:global_step/sec: 2.12714
# INFO:tensorflow:loss = 0.00854588, step = 45800 (47.012 sec)
# INFO:tensorflow:global_step/sec: 2.12356
# INFO:tensorflow:loss = 0.008935406, step = 45900 (47.091 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 46000...
# INFO:tensorflow:Saving checkpoints for 46000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 46000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T19:32:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-46000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 355.44318s
# INFO:tensorflow:Finished evaluation at 2025-01-06-19:38:55
# INFO:tensorflow:Saving dict for global step 46000: global_step = 46000, label/mean = -0.9424408, loss = 0.004238213, mae = 0.036877543, mse = 0.0042381883, prediction/mean = -0.9195961, rho = 0.9866168
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46000: cp_dl_models_04012025_centralized/model.ckpt-46000
# INFO:tensorflow:global_step/sec: 0.225066
# INFO:tensorflow:loss = 0.013554173, step = 46000 (444.314 sec)
# INFO:tensorflow:global_step/sec: 2.14552
# INFO:tensorflow:loss = 0.008179776, step = 46100 (46.609 sec)
# INFO:tensorflow:global_step/sec: 2.14566
# INFO:tensorflow:loss = 0.013214185, step = 46200 (46.607 sec)
# INFO:tensorflow:global_step/sec: 2.15034
# INFO:tensorflow:loss = 0.0107861785, step = 46300 (46.504 sec)
# INFO:tensorflow:global_step/sec: 2.14259
# INFO:tensorflow:loss = 0.020996338, step = 46400 (46.673 sec)
# INFO:tensorflow:global_step/sec: 2.12205
# INFO:tensorflow:loss = 0.022148866, step = 46500 (47.124 sec)
# INFO:tensorflow:global_step/sec: 2.1353
# INFO:tensorflow:loss = 0.0151851075, step = 46600 (46.832 sec)
# INFO:tensorflow:global_step/sec: 2.12365
# INFO:tensorflow:loss = 0.013160793, step = 46700 (47.088 sec)
# INFO:tensorflow:global_step/sec: 2.12663
# INFO:tensorflow:loss = 0.025202025, step = 46800 (47.023 sec)
# INFO:tensorflow:global_step/sec: 2.11792
# INFO:tensorflow:loss = 0.027585708, step = 46900 (47.216 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 47000...
# INFO:tensorflow:Saving checkpoints for 47000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 47000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T19:46:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-47000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.00427s
# INFO:tensorflow:Finished evaluation at 2025-01-06-19:52:41
# INFO:tensorflow:Saving dict for global step 47000: global_step = 47000, label/mean = -0.94243884, loss = 0.0018789606, mae = 0.02580176, mse = 0.0018791523, prediction/mean = -0.95153743, rho = 0.9883672
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47000: cp_dl_models_04012025_centralized/model.ckpt-47000
# INFO:tensorflow:global_step/sec: 0.247148
# INFO:tensorflow:loss = 0.022125883, step = 47000 (404.616 sec)
# INFO:tensorflow:global_step/sec: 2.13303
# INFO:tensorflow:loss = 0.012424643, step = 47100 (46.882 sec)
# INFO:tensorflow:global_step/sec: 2.12545
# INFO:tensorflow:loss = 0.022607474, step = 47200 (47.050 sec)
# INFO:tensorflow:global_step/sec: 2.13891
# INFO:tensorflow:loss = 0.008912374, step = 47300 (46.752 sec)
# INFO:tensorflow:global_step/sec: 2.13163
# INFO:tensorflow:loss = 0.02618331, step = 47400 (46.913 sec)
# INFO:tensorflow:global_step/sec: 2.1272
# INFO:tensorflow:loss = 0.018691806, step = 47500 (47.010 sec)
# INFO:tensorflow:global_step/sec: 2.11627
# INFO:tensorflow:loss = 0.023431467, step = 47600 (47.253 sec)
# INFO:tensorflow:global_step/sec: 2.12995
# INFO:tensorflow:loss = 0.0206702, step = 47700 (46.949 sec)
# INFO:tensorflow:global_step/sec: 2.12683
# INFO:tensorflow:loss = 0.06660501, step = 47800 (47.019 sec)
# INFO:tensorflow:global_step/sec: 2.14196
# INFO:tensorflow:loss = 0.011852559, step = 47900 (46.686 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 48000...
# INFO:tensorflow:Saving checkpoints for 48000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 48000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T20:00:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-48000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 362.63208s
# INFO:tensorflow:Finished evaluation at 2025-01-06-20:06:38
# INFO:tensorflow:Saving dict for global step 48000: global_step = 48000, label/mean = -0.94244015, loss = 0.00224484, mae = 0.028108738, mse = 0.0022448478, prediction/mean = -0.91930586, rho = 0.9890306
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48000: cp_dl_models_04012025_centralized/model.ckpt-48000
# INFO:tensorflow:global_step/sec: 0.241192
# INFO:tensorflow:loss = 0.011460501, step = 48000 (414.607 sec)
# INFO:tensorflow:global_step/sec: 2.15641
# INFO:tensorflow:loss = 0.013458211, step = 48100 (46.374 sec)
# INFO:tensorflow:global_step/sec: 2.14947
# INFO:tensorflow:loss = 0.07830215, step = 48200 (46.523 sec)
# INFO:tensorflow:global_step/sec: 2.15198
# INFO:tensorflow:loss = 0.0111866705, step = 48300 (46.470 sec)
# INFO:tensorflow:global_step/sec: 2.1593
# INFO:tensorflow:loss = 0.013601458, step = 48400 (46.311 sec)
# INFO:tensorflow:global_step/sec: 2.14992
# INFO:tensorflow:loss = 0.0063946377, step = 48500 (46.514 sec)
# INFO:tensorflow:global_step/sec: 2.16067
# INFO:tensorflow:loss = 0.01381385, step = 48600 (46.282 sec)
# INFO:tensorflow:global_step/sec: 2.1554
# INFO:tensorflow:loss = 0.020390008, step = 48700 (46.395 sec)
# INFO:tensorflow:global_step/sec: 2.14901
# INFO:tensorflow:loss = 0.09683732, step = 48800 (46.533 sec)
# INFO:tensorflow:global_step/sec: 2.15226
# INFO:tensorflow:loss = 0.011878061, step = 48900 (46.463 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 49000...
# INFO:tensorflow:Saving checkpoints for 49000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 49000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T20:14:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-49000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 384.31288s
# INFO:tensorflow:Finished evaluation at 2025-01-06-20:20:48
# INFO:tensorflow:Saving dict for global step 49000: global_step = 49000, label/mean = -0.9424404, loss = 0.001459413, mae = 0.024572972, mse = 0.001459481, prediction/mean = -0.9409145, rho = 0.9903626
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49000: cp_dl_models_04012025_centralized/model.ckpt-49000
# INFO:tensorflow:global_step/sec: 0.231432
# INFO:tensorflow:loss = 0.017727755, step = 49000 (432.093 sec)
# INFO:tensorflow:global_step/sec: 2.10257
# INFO:tensorflow:loss = 0.00920385, step = 49100 (47.561 sec)
# INFO:tensorflow:global_step/sec: 2.1139
# INFO:tensorflow:loss = 0.009376256, step = 49200 (47.306 sec)
# INFO:tensorflow:global_step/sec: 2.10858
# INFO:tensorflow:loss = 0.0117761055, step = 49300 (47.425 sec)
# INFO:tensorflow:global_step/sec: 2.12368
# INFO:tensorflow:loss = 0.019941524, step = 49400 (47.088 sec)
# INFO:tensorflow:global_step/sec: 2.13236
# INFO:tensorflow:loss = 0.008993895, step = 49500 (46.896 sec)
# INFO:tensorflow:global_step/sec: 2.13549
# INFO:tensorflow:loss = 0.058941483, step = 49600 (46.827 sec)
# INFO:tensorflow:global_step/sec: 2.15936
# INFO:tensorflow:loss = 0.0065810294, step = 49700 (46.310 sec)
# INFO:tensorflow:global_step/sec: 2.19118
# INFO:tensorflow:loss = 0.01208396, step = 49800 (45.638 sec)
# INFO:tensorflow:global_step/sec: 2.19262
# INFO:tensorflow:loss = 0.004734949, step = 49900 (45.607 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 50000...
# INFO:tensorflow:Saving checkpoints for 50000 into cp_dl_models_04012025_centralized/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 50000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T20:28:36
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_centralized/model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 356.14891s
# INFO:tensorflow:Finished evaluation at 2025-01-06-20:34:32
# INFO:tensorflow:Saving dict for global step 50000: global_step = 50000, label/mean = -0.94244015, loss = 0.002019122, mae = 0.02216238, mse = 0.0020189781, prediction/mean = -0.9349397, rho = 0.98861814
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50000: cp_dl_models_04012025_centralized/model.ckpt-50000
# INFO:tensorflow:Loss for final step: 0.06378669.
# CPU times: user 1d 15h 1min 18s, sys: 5h 2min 54s, total: 1d 20h 4min 13s
# Wall time: 11h 42min 12s
