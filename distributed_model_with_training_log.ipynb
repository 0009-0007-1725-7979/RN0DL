# %% [markdown]
# This Jupyter Notebook includes code adapted from the RouteNet project.
#
# Original author:
# - Krzysztof Rusek
#   AGH University of Science and Technology, Department of Communications, Krakow, Poland.
#   Email: krusek@agh.edu.pl
#
# This code is licensed under the BSD 3-Clause License. See the LICENSE file in this repository for details.

# %%
# TF2.x
import tensorflow.compat.v1 as tf

# TF1.x
# import tensorflow as tf

from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

from tensorflow import keras

import numpy as np
from dataclasses import dataclass, field
from typing import Optional
import glob

# %%
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.15.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
def parse(serialized, target='delay'): #Target is the name of predicted variable
    
    with tf.name_scope('parse'):    
        features = tf.parse_single_example(
            serialized,
            features={
                'traffic':tf.VarLenFeature(tf.float32),
                target:tf.VarLenFeature(tf.float32),
                'links':tf.VarLenFeature(tf.int64),
                'paths':tf.VarLenFeature(tf.int64),
                'sequances':tf.VarLenFeature(tf.int64),
                'n_links':tf.FixedLenFeature([],tf.int64), 
                'n_paths':tf.FixedLenFeature([],tf.int64),
                'n_total':tf.FixedLenFeature([],tf.int64)
            }
        )
        
        for k in ['traffic',target,'links','paths','sequances']:
            features[k] = tf.sparse_tensor_to_dense(features[k])
            if k == 'delay':
                features[k] = (features[k]-2.8)/2.5
            if k == 'traffic':
                #features[k] = (features[k]-0.76)/.008
                features[k] = (features[k]-0.5)/.5
            if k == 'drops':
                features[k] = (features[k])/12000/(0.5*features['traffic']+0.5) #loss rate
            #if k == 'jitter':
                #features[k] = (tf.math.log( features[k] )-2.0)/2.0 #logjitter
            
    return {k:v for k,v in features.items() if k is not target },features[target]

# %%
def tfrecord_input_fn(filenames,hparams,shuffle_buf=1000, target='delay'):
    
    files = tf.data.Dataset.from_tensor_slices(filenames)
    files = files.shuffle(len(filenames))

    ds = files.interleave(tf.data.TFRecordDataset, cycle_length=4)

    if shuffle_buf:
        ds = ds.shuffle(shuffle_buf).repeat()
    
    # ds = ds.map(lambda buf:parse(buf,target), num_parallel_calls=2)
    ds = ds.map(lambda buf:parse(buf,target), num_parallel_calls=tf.data.AUTOTUNE)

    shapes=(
        {
        'traffic':[hparams.node_count*(hparams.node_count-1)],
        'links':[-1],
        'paths':[-1],
        'sequances':[-1],
        'n_links':[],
        'n_paths':[],
        'n_total':[]
        },
        [hparams.node_count*(hparams.node_count-1)]
    )
    
    ds = ds.padded_batch(hparams.batch_size,shapes)
    ds = ds.prefetch(1)
    
    return ds

# %%
class ComnetModel(tf.keras.Model):
    def __init__(self,hparams, output_units=1):
        super(ComnetModel, self).__init__()
        self.hparams = hparams

        self.edge_update = tf.nn.rnn_cell.GRUCell(hparams.link_state_dim, dtype=tf.float32)
        self.path_update = tf.nn.rnn_cell.GRUCell(hparams.path_state_dim, dtype=tf.float32)
        # self.edge_update = tf.keras.layers.GRUCell(hparams.link_state_dim)
        # self.path_update = tf.keras.layers.GRUCell(hparams.path_state_dim)
        
        self.readout = tf.keras.models.Sequential()
        
        self.readout.add(keras.layers.Dense(hparams.readout_units, activation=tf.nn.selu, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
        self.readout.add(keras.layers.Dropout(rate=hparams.dropout_rate))
        
        self.readout.add(keras.layers.Dense(hparams.readout_units, activation=tf.nn.selu, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
        self.readout.add(keras.layers.Dropout(rate=hparams.dropout_rate))
        
        self.readout.add(keras.layers.Dense(output_units, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
            
    def build(self, input_shape=None):
        del input_shape
        self.edge_update.build(tf.TensorShape([None,self.hparams.path_state_dim]))
        self.path_update.build(tf.TensorShape([None,self.hparams.link_state_dim]))
        self.readout.build(input_shape = [None,self.hparams.path_state_dim])
        self.built = True

    def call(self, inputs, training=False):
        f_ = inputs
        shape = tf.stack([f_['n_links'],self.hparams.link_state_dim], axis=0)
        link_state = tf.zeros(shape)
        shape = tf.stack([f_['n_paths'],self.hparams.path_state_dim-1], axis=0)
        path_state = tf.concat([tf.expand_dims(f_['traffic'],axis=1), tf.zeros(shape)], axis=1)

        links = f_['links'][0:f_["n_total"]]
        paths = f_['paths'][0:f_["n_total"]]
        seqs=  f_['sequances'][0:f_["n_total"]]
        
        for _ in range(self.hparams.T):
        
            h_tild = tf.gather(link_state,links)

            ids=tf.stack([paths, seqs], axis=1)            
            max_len = tf.reduce_max(seqs)+1
            shape = tf.stack([f_['n_paths'], max_len, self.hparams.link_state_dim])
            lens = tf.segment_sum(data=tf.ones_like(paths), segment_ids=paths)

            link_inputs = tf.scatter_nd(ids, h_tild, shape)
            outputs, path_state = tf.nn.dynamic_rnn(self.path_update,link_inputs,sequence_length=lens,initial_state=path_state,dtype=tf.float32)
            m = tf.gather_nd(outputs,ids)
            m = tf.unsorted_segment_sum(m, links ,f_['n_links'])
            _,link_state = self.edge_update(m, link_state)
        
        r = self.readout(path_state,training=training)
        
        return r

# %%
def streaming_pearson_correlation_dl(labels, predictions, weights=None):
    """
    Compute streaming Pearson correlation with distributed training compatibility.
    Handles both single-replica and multi-replica contexts.
    Returns (value_tensor, update_op) for use in eval_metric_ops.
    """
    global learning_strategy
    
    # Cast inputs to float32 for compatibility
    labels = tf.cast(labels, tf.float32)
    predictions = tf.cast(predictions, tf.float32)

    # Batch-wise computations
    batch_size = tf.cast(tf.size(labels), tf.float32)
    batch_mean_x = tf.reduce_mean(predictions)
    batch_mean_y = tf.reduce_mean(labels)
    batch_mean_x_squared = tf.reduce_mean(tf.square(predictions))
    batch_mean_y_squared = tf.reduce_mean(tf.square(labels))
    batch_mean_xy = tf.reduce_mean(predictions * labels)

    # Use tf.metrics to accumulate streaming values
    mean_x, update_mean_x = tf.metrics.mean(batch_mean_x, weights)
    mean_y, update_mean_y = tf.metrics.mean(batch_mean_y, weights)
    mean_x_squared, update_mean_x_squared = tf.metrics.mean(batch_mean_x_squared, weights)
    mean_y_squared, update_mean_y_squared = tf.metrics.mean(batch_mean_y_squared, weights)
    mean_xy, update_mean_xy = tf.metrics.mean(batch_mean_xy, weights)
    count, update_count = tf.metrics.mean(batch_size, weights)

    # Compute Pearson correlation
    def compute_correlation():
        covariance = mean_xy - mean_x * mean_y
        variance_x = mean_x_squared - tf.square(mean_x)
        variance_y = mean_y_squared - tf.square(mean_y)
        denominator = tf.sqrt(variance_x * variance_y)
        return tf.where(tf.greater(denominator, 0), covariance / denominator, 0.0)

    rho = compute_correlation()

    # Group all update ops
    update_op = tf.group(
        update_mean_x, update_mean_y, update_mean_x_squared,
        update_mean_y_squared, update_mean_xy, update_count
    )

    # Distributed training compatibility
    if learning_strategy and learning_strategy.num_replicas_in_sync > 1:
        
        # Aggregate distributed values using the strategy context
        def aggregate_rho(learning_strategy, rho):
            return learning_strategy.reduce(tf.distribute.ReduceOp.MEAN, rho, axis=None)

        # Use merge_call to enter cross-replica context
        rho = tf.distribute.get_replica_context().merge_call(lambda ctx: aggregate_rho(ctx, rho))

    return rho, update_op

# %%
def model_fn(features, labels, mode, params):
    
    model = ComnetModel(params)
    model.build()
    #model.summary()

    predictions = tf.map_fn(lambda x: model(x,training=mode==tf.estimator.ModeKeys.TRAIN), features,dtype=tf.float32)
    #predictions = model(features,training=mode==tf.estimator.ModeKeys.TRAIN)
    predictions = tf.squeeze(predictions)

    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions={'predictions':predictions})

    loss =  tf.losses.mean_squared_error(labels=labels, predictions = predictions, reduction=tf.losses.Reduction.MEAN)

    regularization_loss = sum(model.losses)
    total_loss = loss + regularization_loss
    
    tf.summary.scalar('loss', loss)
    tf.summary.scalar('regularization_loss', regularization_loss)

    if mode == tf.estimator.ModeKeys.EVAL:
        
        return tf.estimator.EstimatorSpec(
            mode,
            loss=loss,
            eval_metric_ops=
            {
                'label/mean':tf.metrics.mean(labels),
                'prediction/mean': tf.metrics.mean(predictions),
                
                'mae':tf.metrics.mean_absolute_error(labels, predictions),
                'mse': tf.metrics.mean_squared_error(labels=labels, predictions=predictions),
                
                #'rho_contrib':tf.contrib.metrics.streaming_pearson_correlation(labels=labels,predictions=predictions),
                'rho': streaming_pearson_correlation_dl(labels, predictions)
            }
        )
    
    assert mode == tf.estimator.ModeKeys.TRAIN

    trainables = model.variables
    grads = tf.gradients(total_loss, trainables)
    grad_var_pairs = zip(grads, trainables)

    summaries = [tf.summary.histogram(var.op.name, var) for var in trainables]
    summaries += [tf.summary.histogram(g.op.name, g) for g in grads if g is not None]

    optimizer=tf.train.AdamOptimizer(params.learning_rate)
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    
    with tf.control_dependencies(update_ops):
        train_op = optimizer.apply_gradients(grad_var_pairs, global_step=tf.train.get_global_step())

    return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op,)

# %%
def train(args):
    
    print(args.hparams)
    tf.logging.set_verbosity('INFO')

    global learning_strategy
    learning_strategy = args.strategy

    my_checkpointing_config = tf.estimator.RunConfig(
        train_distribute=args.strategy,
        eval_distribute=args.strategy,
        save_checkpoints_steps=1000,
        keep_checkpoint_max=50
    )

    estimator = tf.estimator.Estimator(
        model_fn=model_fn, 
        model_dir=args.model_dir, 
        params=args.hparams, 
        warm_start_from=args.warm, 
        config=my_checkpointing_config)

    train_spec = tf.estimator.TrainSpec(input_fn=lambda:tfrecord_input_fn(args.train,args.hparams,shuffle_buf=args.shuffle_buf,target=args.target),max_steps=args.train_steps)
    eval_spec = tf.estimator.EvalSpec(input_fn=lambda:tfrecord_input_fn(args.eval_,args.hparams,shuffle_buf=None,target=args.target),steps=args.eval_steps,throttle_secs=1)

    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %%
tfrecord_train_files = glob.glob("nsfnet/tfrecords/train/*.tfrecords")
tfrecord_eval_files = glob.glob("nsfnet/tfrecords/evaluate/*.tfrecords")

@dataclass
class HyperParams:
    node_count: int = 14
    link_state_dim: int = 16
    path_state_dim: int = 32
    T: int = 8
    readout_units: int = 256
    learning_rate: float = 0.001
    batch_size: int = 32
    dropout_rate: float = 0.5
    l2: float = 0.1
    l2_2: float = 0.01

@dataclass
class Args:
    target: str = "delay"
    strategy: Optional[str] = tf.distribute.MirroredStrategy() #None
    hparams: HyperParams = HyperParams()
    train: list = field(default_factory=lambda: tfrecord_train_files)
    eval_: list = field(default_factory=lambda: tfrecord_eval_files)
    model_dir: str = "cp_dl_models_04012025_distributed"
    train_steps: int = 50000
    eval_steps: Optional[int] = None
    shuffle_buf: int = 30000
    warm: Optional[str] = None

args = Args()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %%
# %time train(args)
# Out:
# HyperParams(node_count=14, link_state_dim=16, path_state_dim=32, T=8, readout_units=256, learning_rate=0.001, batch_size=32, dropout_rate=0.5, l2=0.1, l2_2=0.01)
# INFO:tensorflow:Initializing RunConfig with distribution strategies.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Using config: {'_model_dir': 'cp_dl_models_04012025_distributed', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 50, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': <tensorflow.python.distribute.mirrored_strategy.MirroredStrategyV1 object at 0x1517ec106d10>, '_device_fn': None, '_protocol': None, '_eval_distribute': <tensorflow.python.distribute.mirrored_strategy.MirroredStrategyV1 object at 0x1517ec106d10>, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_distribute_coordinator_mode': None}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Collective all_reduce tensors: 14 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 2.660859, step = 0
# INFO:tensorflow:global_step/sec: 1.90135
# INFO:tensorflow:loss = 0.33555228, step = 100 (52.596 sec)
# INFO:tensorflow:global_step/sec: 2.043
# INFO:tensorflow:loss = 0.1899043, step = 200 (48.947 sec)
# INFO:tensorflow:global_step/sec: 2.0415
# INFO:tensorflow:loss = 0.10065676, step = 300 (48.984 sec)
# INFO:tensorflow:global_step/sec: 2.04672
# INFO:tensorflow:loss = 0.1793797, step = 400 (48.859 sec)
# INFO:tensorflow:global_step/sec: 2.0497
# INFO:tensorflow:loss = 0.07599151, step = 500 (48.788 sec)
# INFO:tensorflow:global_step/sec: 2.04478
# INFO:tensorflow:loss = 0.09052162, step = 600 (48.905 sec)
# INFO:tensorflow:global_step/sec: 2.05853
# INFO:tensorflow:loss = 0.07371394, step = 700 (48.578 sec)
# INFO:tensorflow:global_step/sec: 2.03981
# INFO:tensorflow:loss = 0.19289981, step = 800 (49.024 sec)
# INFO:tensorflow:global_step/sec: 2.03604
# INFO:tensorflow:loss = 0.05148043, step = 900 (49.115 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T19:10:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 180.03959s
# INFO:tensorflow:Finished evaluation at 2025-01-05-19:13:55
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, label/mean = -0.9426438, loss = 0.010239251, mae = 0.048854426, mse = 0.010239252, prediction/mean = -0.9323344, rho = 0.93395936
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: cp_dl_models_04012025_distributed/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 0.430578
# INFO:tensorflow:loss = 0.068265244, step = 1000 (232.245 sec)
# INFO:tensorflow:global_step/sec: 2.02981
# INFO:tensorflow:loss = 0.05931374, step = 1100 (49.266 sec)
# INFO:tensorflow:global_step/sec: 1.99463
# INFO:tensorflow:loss = 0.039068557, step = 1200 (50.135 sec)
# INFO:tensorflow:global_step/sec: 2.02512
# INFO:tensorflow:loss = 0.050516944, step = 1300 (49.380 sec)
# INFO:tensorflow:global_step/sec: 2.05125
# INFO:tensorflow:loss = 0.060903892, step = 1400 (48.751 sec)
# INFO:tensorflow:global_step/sec: 2.04592
# INFO:tensorflow:loss = 0.037385754, step = 1500 (48.878 sec)
# INFO:tensorflow:global_step/sec: 2.08675
# INFO:tensorflow:loss = 0.13700749, step = 1600 (47.921 sec)
# INFO:tensorflow:global_step/sec: 2.09537
# INFO:tensorflow:loss = 0.07424563, step = 1700 (47.724 sec)
# INFO:tensorflow:global_step/sec: 2.07965
# INFO:tensorflow:loss = 0.061333496, step = 1800 (48.085 sec)
# INFO:tensorflow:global_step/sec: 2.06355
# INFO:tensorflow:loss = 0.04728695, step = 1900 (48.460 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2000...
# INFO:tensorflow:Saving checkpoints for 2000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T19:22:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.26901s
# INFO:tensorflow:Finished evaluation at 2025-01-05-19:25:03
# INFO:tensorflow:Saving dict for global step 2000: global_step = 2000, label/mean = -0.9426437, loss = 0.0060930485, mae = 0.042357326, mse = 0.006093052, prediction/mean = -0.91045195, rho = 0.9686702
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: cp_dl_models_04012025_distributed/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 0.43671
# INFO:tensorflow:loss = 0.121970445, step = 2000 (228.985 sec)
# INFO:tensorflow:global_step/sec: 2.04594
# INFO:tensorflow:loss = 0.12135337, step = 2100 (48.878 sec)
# INFO:tensorflow:global_step/sec: 2.06892
# INFO:tensorflow:loss = 0.07594986, step = 2200 (48.335 sec)
# INFO:tensorflow:global_step/sec: 2.10841
# INFO:tensorflow:loss = 0.07316956, step = 2300 (47.428 sec)
# INFO:tensorflow:global_step/sec: 2.05326
# INFO:tensorflow:loss = 0.05174616, step = 2400 (48.703 sec)
# INFO:tensorflow:global_step/sec: 2.05635
# INFO:tensorflow:loss = 0.09512861, step = 2500 (48.630 sec)
# INFO:tensorflow:global_step/sec: 2.01013
# INFO:tensorflow:loss = 0.09099565, step = 2600 (49.748 sec)
# INFO:tensorflow:global_step/sec: 2.01102
# INFO:tensorflow:loss = 0.03726902, step = 2700 (49.726 sec)
# INFO:tensorflow:global_step/sec: 2.02617
# INFO:tensorflow:loss = 0.10875929, step = 2800 (49.354 sec)
# INFO:tensorflow:global_step/sec: 2.01996
# INFO:tensorflow:loss = 0.07150927, step = 2900 (49.506 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3000...
# INFO:tensorflow:Saving checkpoints for 3000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T19:33:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.06768s
# INFO:tensorflow:Finished evaluation at 2025-01-05-19:36:12
# INFO:tensorflow:Saving dict for global step 3000: global_step = 3000, label/mean = -0.9426442, loss = 0.0045624757, mae = 0.033516504, mse = 0.0045624766, prediction/mean = -0.9132102, rho = 0.9763596
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: cp_dl_models_04012025_distributed/model.ckpt-3000
# INFO:tensorflow:global_step/sec: 0.436884
# INFO:tensorflow:loss = 0.09652798, step = 3000 (228.893 sec)
# INFO:tensorflow:global_step/sec: 2.02475
# INFO:tensorflow:loss = 0.057227984, step = 3100 (49.389 sec)
# INFO:tensorflow:global_step/sec: 2.02589
# INFO:tensorflow:loss = 0.032294214, step = 3200 (49.361 sec)
# INFO:tensorflow:global_step/sec: 2.01342
# INFO:tensorflow:loss = 0.07840659, step = 3300 (49.666 sec)
# INFO:tensorflow:global_step/sec: 2.02418
# INFO:tensorflow:loss = 0.0674433, step = 3400 (49.403 sec)
# INFO:tensorflow:global_step/sec: 2.03572
# INFO:tensorflow:loss = 0.050080724, step = 3500 (49.123 sec)
# INFO:tensorflow:global_step/sec: 2.11935
# INFO:tensorflow:loss = 0.052445374, step = 3600 (47.184 sec)
# INFO:tensorflow:global_step/sec: 2.09615
# INFO:tensorflow:loss = 0.07908999, step = 3700 (47.706 sec)
# INFO:tensorflow:global_step/sec: 2.06851
# INFO:tensorflow:loss = 0.040792942, step = 3800 (48.344 sec)
# INFO:tensorflow:global_step/sec: 2.05784
# INFO:tensorflow:loss = 0.061209615, step = 3900 (48.595 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4000...
# INFO:tensorflow:Saving checkpoints for 4000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T19:44:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.62354s
# INFO:tensorflow:Finished evaluation at 2025-01-05-19:47:24
# INFO:tensorflow:Saving dict for global step 4000: global_step = 4000, label/mean = -0.9424291, loss = 0.005438171, mae = 0.04081225, mse = 0.0054381643, prediction/mean = -0.95962495, rho = 0.96734625
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: cp_dl_models_04012025_distributed/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 0.430264
# INFO:tensorflow:loss = 0.04573695, step = 4000 (232.415 sec)
# INFO:tensorflow:global_step/sec: 2.0299
# INFO:tensorflow:loss = 0.061150502, step = 4100 (49.264 sec)
# INFO:tensorflow:global_step/sec: 2.01523
# INFO:tensorflow:loss = 0.054486386, step = 4200 (49.622 sec)
# INFO:tensorflow:global_step/sec: 2.01997
# INFO:tensorflow:loss = 0.026214542, step = 4300 (49.506 sec)
# INFO:tensorflow:global_step/sec: 2.00564
# INFO:tensorflow:loss = 0.084494516, step = 4400 (49.882 sec)
# INFO:tensorflow:global_step/sec: 2.01969
# INFO:tensorflow:loss = 0.030072205, step = 4500 (49.489 sec)
# INFO:tensorflow:global_step/sec: 2.02221
# INFO:tensorflow:loss = 0.10979241, step = 4600 (49.451 sec)
# INFO:tensorflow:global_step/sec: 2.02989
# INFO:tensorflow:loss = 0.039615545, step = 4700 (49.264 sec)
# INFO:tensorflow:global_step/sec: 2.0566
# INFO:tensorflow:loss = 0.08412815, step = 4800 (48.624 sec)
# INFO:tensorflow:global_step/sec: 2.05841
# INFO:tensorflow:loss = 0.07381386, step = 4900 (48.581 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T19:55:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.21057s
# INFO:tensorflow:Finished evaluation at 2025-01-05-19:58:36
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, label/mean = -0.9426439, loss = 0.0036765696, mae = 0.030203586, mse = 0.0036765682, prediction/mean = -0.92268455, rho = 0.9779344
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: cp_dl_models_04012025_distributed/model.ckpt-5000
# INFO:tensorflow:global_step/sec: 0.437627
# INFO:tensorflow:loss = 0.043543465, step = 5000 (228.505 sec)
# INFO:tensorflow:global_step/sec: 2.04771
# INFO:tensorflow:loss = 0.04555558, step = 5100 (48.836 sec)
# INFO:tensorflow:global_step/sec: 2.0433
# INFO:tensorflow:loss = 0.058551684, step = 5200 (48.940 sec)
# INFO:tensorflow:global_step/sec: 2.03222
# INFO:tensorflow:loss = 0.065200396, step = 5300 (49.208 sec)
# INFO:tensorflow:global_step/sec: 2.05708
# INFO:tensorflow:loss = 0.05171218, step = 5400 (48.612 sec)
# INFO:tensorflow:global_step/sec: 2.03688
# INFO:tensorflow:loss = 0.047242016, step = 5500 (49.095 sec)
# INFO:tensorflow:global_step/sec: 2.05175
# INFO:tensorflow:loss = 0.07944031, step = 5600 (48.739 sec)
# INFO:tensorflow:global_step/sec: 2.00749
# INFO:tensorflow:loss = 0.17207344, step = 5700 (49.813 sec)
# INFO:tensorflow:global_step/sec: 2.03146
# INFO:tensorflow:loss = 0.075608015, step = 5800 (49.226 sec)
# INFO:tensorflow:global_step/sec: 2.01497
# INFO:tensorflow:loss = 0.05739392, step = 5900 (49.628 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6000...
# INFO:tensorflow:Saving checkpoints for 6000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T20:06:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.49129s
# INFO:tensorflow:Finished evaluation at 2025-01-05-20:09:47
# INFO:tensorflow:Saving dict for global step 6000: global_step = 6000, label/mean = -0.9426438, loss = 0.0039723082, mae = 0.038893078, mse = 0.003972311, prediction/mean = -0.9653088, rho = 0.98207223
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: cp_dl_models_04012025_distributed/model.ckpt-6000
# INFO:tensorflow:global_step/sec: 0.436093
# INFO:tensorflow:loss = 0.04677634, step = 6000 (229.308 sec)
# INFO:tensorflow:global_step/sec: 2.03872
# INFO:tensorflow:loss = 0.110194966, step = 6100 (49.051 sec)
# INFO:tensorflow:global_step/sec: 2.04433
# INFO:tensorflow:loss = 0.026889635, step = 6200 (48.916 sec)
# INFO:tensorflow:global_step/sec: 2.07134
# INFO:tensorflow:loss = 0.06264953, step = 6300 (48.278 sec)
# INFO:tensorflow:global_step/sec: 2.02765
# INFO:tensorflow:loss = 0.08207201, step = 6400 (49.318 sec)
# INFO:tensorflow:global_step/sec: 1.73754
# INFO:tensorflow:loss = 0.031473346, step = 6500 (57.552 sec)
# INFO:tensorflow:global_step/sec: 2.03814
# INFO:tensorflow:loss = 0.088803284, step = 6600 (49.065 sec)
# INFO:tensorflow:global_step/sec: 2.03617
# INFO:tensorflow:loss = 0.020231757, step = 6700 (49.112 sec)
# INFO:tensorflow:global_step/sec: 2.0403
# INFO:tensorflow:loss = 0.032379843, step = 6800 (49.012 sec)
# INFO:tensorflow:global_step/sec: 2.04196
# INFO:tensorflow:loss = 0.051368896, step = 6900 (48.973 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 7000...
# INFO:tensorflow:Saving checkpoints for 7000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 7000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T20:18:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.38748s
# INFO:tensorflow:Finished evaluation at 2025-01-05-20:21:06
# INFO:tensorflow:Saving dict for global step 7000: global_step = 7000, label/mean = -0.9426431, loss = 0.0031918383, mae = 0.026885483, mse = 0.0031918383, prediction/mean = -0.9221412, rho = 0.984285
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: cp_dl_models_04012025_distributed/model.ckpt-7000
# INFO:tensorflow:global_step/sec: 0.436211
# INFO:tensorflow:loss = 0.091601565, step = 7000 (229.246 sec)
# INFO:tensorflow:global_step/sec: 2.02202
# INFO:tensorflow:loss = 0.05275292, step = 7100 (49.456 sec)
# INFO:tensorflow:global_step/sec: 2.01156
# INFO:tensorflow:loss = 0.12373208, step = 7200 (49.712 sec)
# INFO:tensorflow:global_step/sec: 2.04144
# INFO:tensorflow:loss = 0.07023543, step = 7300 (48.986 sec)
# INFO:tensorflow:global_step/sec: 2.03333
# INFO:tensorflow:loss = 0.031881075, step = 7400 (49.181 sec)
# INFO:tensorflow:global_step/sec: 2.04958
# INFO:tensorflow:loss = 0.027810091, step = 7500 (48.790 sec)
# INFO:tensorflow:global_step/sec: 2.05196
# INFO:tensorflow:loss = 0.07207139, step = 7600 (48.734 sec)
# INFO:tensorflow:global_step/sec: 2.06328
# INFO:tensorflow:loss = 0.035617076, step = 7700 (48.466 sec)
# INFO:tensorflow:global_step/sec: 2.07062
# INFO:tensorflow:loss = 0.027695261, step = 7800 (48.294 sec)
# INFO:tensorflow:global_step/sec: 2.0702
# INFO:tensorflow:loss = 0.05212563, step = 7900 (48.305 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8000...
# INFO:tensorflow:Saving checkpoints for 8000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T20:29:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 223.98377s
# INFO:tensorflow:Finished evaluation at 2025-01-05-20:33:01
# INFO:tensorflow:Saving dict for global step 8000: global_step = 8000, label/mean = -0.94264394, loss = 0.0021415935, mae = 0.024861299, mse = 0.0021415935, prediction/mean = -0.9341061, rho = 0.9868388
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: cp_dl_models_04012025_distributed/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 0.362936
# INFO:tensorflow:loss = 0.04074009, step = 8000 (275.530 sec)
# INFO:tensorflow:global_step/sec: 2.06824
# INFO:tensorflow:loss = 0.08508464, step = 8100 (48.351 sec)
# INFO:tensorflow:global_step/sec: 2.1024
# INFO:tensorflow:loss = 0.034044296, step = 8200 (47.565 sec)
# INFO:tensorflow:global_step/sec: 1.22875
# INFO:tensorflow:loss = 0.0489771, step = 8300 (81.384 sec)
# INFO:tensorflow:global_step/sec: 2.06706
# INFO:tensorflow:loss = 0.017700948, step = 8400 (48.378 sec)
# INFO:tensorflow:global_step/sec: 2.07309
# INFO:tensorflow:loss = 0.14327487, step = 8500 (48.236 sec)
# INFO:tensorflow:global_step/sec: 2.05763
# INFO:tensorflow:loss = 0.0796078, step = 8600 (48.600 sec)
# INFO:tensorflow:global_step/sec: 2.05767
# INFO:tensorflow:loss = 0.074030496, step = 8700 (48.599 sec)
# INFO:tensorflow:global_step/sec: 2.02615
# INFO:tensorflow:loss = 0.039993368, step = 8800 (49.355 sec)
# INFO:tensorflow:global_step/sec: 2.00237
# INFO:tensorflow:loss = 0.021781735, step = 8900 (49.941 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 9000...
# INFO:tensorflow:Saving checkpoints for 9000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 9000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T20:41:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.56826s
# INFO:tensorflow:Finished evaluation at 2025-01-05-20:44:41
# INFO:tensorflow:Saving dict for global step 9000: global_step = 9000, label/mean = -0.9426434, loss = 0.00395503, mae = 0.035645325, mse = 0.0039550355, prediction/mean = -0.95334184, rho = 0.9825527
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: cp_dl_models_04012025_distributed/model.ckpt-9000
# INFO:tensorflow:global_step/sec: 0.43569
# INFO:tensorflow:loss = 0.05787147, step = 9000 (229.520 sec)
# INFO:tensorflow:global_step/sec: 1.99274
# INFO:tensorflow:loss = 0.06087106, step = 9100 (50.183 sec)
# INFO:tensorflow:global_step/sec: 2.02169
# INFO:tensorflow:loss = 0.062124953, step = 9200 (49.463 sec)
# INFO:tensorflow:global_step/sec: 2.03127
# INFO:tensorflow:loss = 0.06072149, step = 9300 (49.231 sec)
# INFO:tensorflow:global_step/sec: 2.05523
# INFO:tensorflow:loss = 0.012822367, step = 9400 (48.656 sec)
# INFO:tensorflow:global_step/sec: 2.04992
# INFO:tensorflow:loss = 0.07212542, step = 9500 (48.783 sec)
# INFO:tensorflow:global_step/sec: 2.05491
# INFO:tensorflow:loss = 0.025833935, step = 9600 (48.664 sec)
# INFO:tensorflow:global_step/sec: 2.06973
# INFO:tensorflow:loss = 0.037080016, step = 9700 (48.315 sec)
# INFO:tensorflow:global_step/sec: 2.06455
# INFO:tensorflow:loss = 0.013387717, step = 9800 (48.437 sec)
# INFO:tensorflow:global_step/sec: 2.07626
# INFO:tensorflow:loss = 0.053655133, step = 9900 (48.164 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T20:52:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.05599s
# INFO:tensorflow:Finished evaluation at 2025-01-05-20:55:49
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, label/mean = -0.94245565, loss = 0.0038537038, mae = 0.03853272, mse = 0.0038537062, prediction/mean = -0.90800923, rho = 0.98212177
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: cp_dl_models_04012025_distributed/model.ckpt-10000
# INFO:tensorflow:global_step/sec: 0.438303
# INFO:tensorflow:loss = 0.07856135, step = 10000 (228.152 sec)
# INFO:tensorflow:global_step/sec: 2.0459
# INFO:tensorflow:loss = 0.04300704, step = 10100 (48.879 sec)
# INFO:tensorflow:global_step/sec: 2.03937
# INFO:tensorflow:loss = 0.03173031, step = 10200 (49.034 sec)
# INFO:tensorflow:global_step/sec: 2.03801
# INFO:tensorflow:loss = 0.084654674, step = 10300 (49.068 sec)
# INFO:tensorflow:global_step/sec: 2.04406
# INFO:tensorflow:loss = 0.06847577, step = 10400 (48.921 sec)
# INFO:tensorflow:global_step/sec: 2.05629
# INFO:tensorflow:loss = 0.122449964, step = 10500 (48.632 sec)
# INFO:tensorflow:global_step/sec: 2.07309
# INFO:tensorflow:loss = 0.0742988, step = 10600 (48.236 sec)
# INFO:tensorflow:global_step/sec: 2.07845
# INFO:tensorflow:loss = 0.03686776, step = 10700 (48.113 sec)
# INFO:tensorflow:global_step/sec: 2.0384
# INFO:tensorflow:loss = 0.06581074, step = 10800 (49.058 sec)
# INFO:tensorflow:global_step/sec: 2.06885
# INFO:tensorflow:loss = 0.082684726, step = 10900 (48.336 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 11000...
# INFO:tensorflow:Saving checkpoints for 11000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 11000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T21:04:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.71950s
# INFO:tensorflow:Finished evaluation at 2025-01-05-21:07:00
# INFO:tensorflow:Saving dict for global step 11000: global_step = 11000, label/mean = -0.9426432, loss = 0.0032154776, mae = 0.036348086, mse = 0.0032154776, prediction/mean = -0.9128989, rho = 0.988807
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: cp_dl_models_04012025_distributed/model.ckpt-11000
# INFO:tensorflow:global_step/sec: 0.429375
# INFO:tensorflow:loss = 0.034536526, step = 11000 (232.896 sec)
# INFO:tensorflow:global_step/sec: 2.02093
# INFO:tensorflow:loss = 0.029481009, step = 11100 (49.483 sec)
# INFO:tensorflow:global_step/sec: 2.05806
# INFO:tensorflow:loss = 0.022170385, step = 11200 (48.589 sec)
# INFO:tensorflow:global_step/sec: 2.10135
# INFO:tensorflow:loss = 0.052443694, step = 11300 (47.589 sec)
# INFO:tensorflow:global_step/sec: 2.066
# INFO:tensorflow:loss = 0.014893035, step = 11400 (48.403 sec)
# INFO:tensorflow:global_step/sec: 2.08007
# INFO:tensorflow:loss = 0.08368902, step = 11500 (48.075 sec)
# INFO:tensorflow:global_step/sec: 2.07702
# INFO:tensorflow:loss = 0.06996362, step = 11600 (48.146 sec)
# INFO:tensorflow:global_step/sec: 2.06129
# INFO:tensorflow:loss = 0.057299715, step = 11700 (48.512 sec)
# INFO:tensorflow:global_step/sec: 2.08592
# INFO:tensorflow:loss = 0.08832885, step = 11800 (47.941 sec)
# INFO:tensorflow:global_step/sec: 2.0995
# INFO:tensorflow:loss = 0.038095348, step = 11900 (47.630 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 12000...
# INFO:tensorflow:Saving checkpoints for 12000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 12000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T21:15:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.82100s
# INFO:tensorflow:Finished evaluation at 2025-01-05-21:18:22
# INFO:tensorflow:Saving dict for global step 12000: global_step = 12000, label/mean = -0.94264394, loss = 0.0025484988, mae = 0.026938248, mse = 0.0025484995, prediction/mean = -0.9216695, rho = 0.9864645
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: cp_dl_models_04012025_distributed/model.ckpt-12000
# INFO:tensorflow:global_step/sec: 0.403599
# INFO:tensorflow:loss = 0.04726677, step = 12000 (247.770 sec)
# INFO:tensorflow:global_step/sec: 2.06611
# INFO:tensorflow:loss = 0.046069697, step = 12100 (48.401 sec)
# INFO:tensorflow:global_step/sec: 2.08212
# INFO:tensorflow:loss = 0.0329473, step = 12200 (48.027 sec)
# INFO:tensorflow:global_step/sec: 2.06541
# INFO:tensorflow:loss = 0.04446914, step = 12300 (48.417 sec)
# INFO:tensorflow:global_step/sec: 2.04852
# INFO:tensorflow:loss = 0.08660362, step = 12400 (48.815 sec)
# INFO:tensorflow:global_step/sec: 2.07112
# INFO:tensorflow:loss = 0.09466009, step = 12500 (48.284 sec)
# INFO:tensorflow:global_step/sec: 2.07904
# INFO:tensorflow:loss = 0.06245361, step = 12600 (48.099 sec)
# INFO:tensorflow:global_step/sec: 2.06999
# INFO:tensorflow:loss = 0.035379793, step = 12700 (48.309 sec)
# INFO:tensorflow:global_step/sec: 2.05009
# INFO:tensorflow:loss = 0.04043234, step = 12800 (48.779 sec)
# INFO:tensorflow:global_step/sec: 2.02152
# INFO:tensorflow:loss = 0.034716308, step = 12900 (49.468 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 13000...
# INFO:tensorflow:Saving checkpoints for 13000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 13000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T21:26:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.66274s
# INFO:tensorflow:Finished evaluation at 2025-01-05-21:29:27
# INFO:tensorflow:Saving dict for global step 13000: global_step = 13000, label/mean = -0.9426437, loss = 0.0035594392, mae = 0.044942044, mse = 0.00355944, prediction/mean = -0.9058605, rho = 0.98885524
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13000: cp_dl_models_04012025_distributed/model.ckpt-13000
# INFO:tensorflow:global_step/sec: 0.437961
# INFO:tensorflow:loss = 0.07752837, step = 13000 (228.331 sec)
# INFO:tensorflow:global_step/sec: 2.00724
# INFO:tensorflow:loss = 0.058825843, step = 13100 (49.820 sec)
# INFO:tensorflow:global_step/sec: 2.03461
# INFO:tensorflow:loss = 0.031305276, step = 13200 (49.150 sec)
# INFO:tensorflow:global_step/sec: 2.04347
# INFO:tensorflow:loss = 0.04662127, step = 13300 (48.936 sec)
# INFO:tensorflow:global_step/sec: 2.00982
# INFO:tensorflow:loss = 0.038886353, step = 13400 (49.756 sec)
# INFO:tensorflow:global_step/sec: 2.00804
# INFO:tensorflow:loss = 0.036278352, step = 13500 (49.800 sec)
# INFO:tensorflow:global_step/sec: 2.02996
# INFO:tensorflow:loss = 0.034423925, step = 13600 (49.262 sec)
# INFO:tensorflow:global_step/sec: 2.0387
# INFO:tensorflow:loss = 0.061099444, step = 13700 (49.052 sec)
# INFO:tensorflow:global_step/sec: 2.02367
# INFO:tensorflow:loss = 0.08581364, step = 13800 (49.415 sec)
# INFO:tensorflow:global_step/sec: 2.03411
# INFO:tensorflow:loss = 0.031927463, step = 13900 (49.161 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 14000...
# INFO:tensorflow:Saving checkpoints for 14000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 14000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T21:37:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.21566s
# INFO:tensorflow:Finished evaluation at 2025-01-05-21:40:41
# INFO:tensorflow:Saving dict for global step 14000: global_step = 14000, label/mean = -0.9426438, loss = 0.0026048874, mae = 0.032841116, mse = 0.002604888, prediction/mean = -0.95481884, rho = 0.9868098
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: cp_dl_models_04012025_distributed/model.ckpt-14000
# INFO:tensorflow:global_step/sec: 0.435296
# INFO:tensorflow:loss = 0.043679595, step = 14000 (229.729 sec)
# INFO:tensorflow:global_step/sec: 1.99318
# INFO:tensorflow:loss = 0.049540047, step = 14100 (50.172 sec)
# INFO:tensorflow:global_step/sec: 1.98835
# INFO:tensorflow:loss = 0.10496838, step = 14200 (50.292 sec)
# INFO:tensorflow:global_step/sec: 2.03144
# INFO:tensorflow:loss = 0.028856104, step = 14300 (49.227 sec)
# INFO:tensorflow:global_step/sec: 2.03845
# INFO:tensorflow:loss = 0.017872157, step = 14400 (49.056 sec)
# INFO:tensorflow:global_step/sec: 2.07611
# INFO:tensorflow:loss = 0.08701291, step = 14500 (48.168 sec)
# INFO:tensorflow:global_step/sec: 2.07197
# INFO:tensorflow:loss = 0.075533606, step = 14600 (48.263 sec)
# INFO:tensorflow:global_step/sec: 2.04337
# INFO:tensorflow:loss = 0.08516726, step = 14700 (48.938 sec)
# INFO:tensorflow:global_step/sec: 2.07429
# INFO:tensorflow:loss = 0.09016091, step = 14800 (48.210 sec)
# INFO:tensorflow:global_step/sec: 2.08707
# INFO:tensorflow:loss = 0.01604622, step = 14900 (47.914 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 15000...
# INFO:tensorflow:Saving checkpoints for 15000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 15000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T21:48:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.70259s
# INFO:tensorflow:Finished evaluation at 2025-01-05-21:51:49
# INFO:tensorflow:Saving dict for global step 15000: global_step = 15000, label/mean = -0.9426436, loss = 0.0020600937, mae = 0.028119477, mse = 0.002060093, prediction/mean = -0.949558, rho = 0.9873883
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: cp_dl_models_04012025_distributed/model.ckpt-15000
# INFO:tensorflow:global_step/sec: 0.440105
# INFO:tensorflow:loss = 0.05167431, step = 15000 (227.218 sec)
# INFO:tensorflow:global_step/sec: 2.10983
# INFO:tensorflow:loss = 0.102634266, step = 15100 (47.397 sec)
# INFO:tensorflow:global_step/sec: 2.12491
# INFO:tensorflow:loss = 0.031008776, step = 15200 (47.061 sec)
# INFO:tensorflow:global_step/sec: 2.11552
# INFO:tensorflow:loss = 0.025882874, step = 15300 (47.269 sec)
# INFO:tensorflow:global_step/sec: 2.09723
# INFO:tensorflow:loss = 0.049326405, step = 15400 (47.682 sec)
# INFO:tensorflow:global_step/sec: 2.07559
# INFO:tensorflow:loss = 0.08723631, step = 15500 (48.179 sec)
# INFO:tensorflow:global_step/sec: 2.05685
# INFO:tensorflow:loss = 0.044760093, step = 15600 (48.618 sec)
# INFO:tensorflow:global_step/sec: 1.99344
# INFO:tensorflow:loss = 0.08877565, step = 15700 (50.164 sec)
# INFO:tensorflow:global_step/sec: 2.01393
# INFO:tensorflow:loss = 0.08924739, step = 15800 (49.654 sec)
# INFO:tensorflow:global_step/sec: 2.03302
# INFO:tensorflow:loss = 0.036460653, step = 15900 (49.188 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 16000...
# INFO:tensorflow:Saving checkpoints for 16000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 16000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T21:59:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.71381s
# INFO:tensorflow:Finished evaluation at 2025-01-05-22:02:53
# INFO:tensorflow:Saving dict for global step 16000: global_step = 16000, label/mean = -0.9426428, loss = 0.0032946519, mae = 0.033602703, mse = 0.0032946528, prediction/mean = -0.9141087, rho = 0.98368335
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: cp_dl_models_04012025_distributed/model.ckpt-16000
# INFO:tensorflow:global_step/sec: 0.437672
# INFO:tensorflow:loss = 0.057254814, step = 16000 (228.481 sec)
# INFO:tensorflow:global_step/sec: 2.01491
# INFO:tensorflow:loss = 0.04684084, step = 16100 (49.630 sec)
# INFO:tensorflow:global_step/sec: 2.00743
# INFO:tensorflow:loss = 0.095855966, step = 16200 (49.816 sec)
# INFO:tensorflow:global_step/sec: 2.00624
# INFO:tensorflow:loss = 0.054279145, step = 16300 (49.844 sec)
# INFO:tensorflow:global_step/sec: 2.0638
# INFO:tensorflow:loss = 0.07160929, step = 16400 (48.455 sec)
# INFO:tensorflow:global_step/sec: 2.06751
# INFO:tensorflow:loss = 0.05313769, step = 16500 (48.367 sec)
# INFO:tensorflow:global_step/sec: 2.10467
# INFO:tensorflow:loss = 0.06029197, step = 16600 (47.513 sec)
# INFO:tensorflow:global_step/sec: 2.06882
# INFO:tensorflow:loss = 0.06536266, step = 16700 (48.337 sec)
# INFO:tensorflow:global_step/sec: 2.04962
# INFO:tensorflow:loss = 0.03929121, step = 16800 (48.789 sec)
# INFO:tensorflow:global_step/sec: 2.07776
# INFO:tensorflow:loss = 0.059854135, step = 16900 (57.154 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 17000...
# INFO:tensorflow:Saving checkpoints for 17000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 17000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T22:11:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.57953s
# INFO:tensorflow:Finished evaluation at 2025-01-05-22:14:35
# INFO:tensorflow:Saving dict for global step 17000: global_step = 17000, label/mean = -0.9426441, loss = 0.005238513, mae = 0.05606549, mse = 0.0052385083, prediction/mean = -0.8983168, rho = 0.98855984
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17000: cp_dl_models_04012025_distributed/model.ckpt-17000
# INFO:tensorflow:global_step/sec: 0.378897
# INFO:tensorflow:loss = 0.032317627, step = 17000 (254.899 sec)
# INFO:tensorflow:global_step/sec: 2.05334
# INFO:tensorflow:loss = 0.09716345, step = 17100 (48.702 sec)
# INFO:tensorflow:global_step/sec: 2.0558
# INFO:tensorflow:loss = 0.018658224, step = 17200 (48.642 sec)
# INFO:tensorflow:global_step/sec: 0.831377
# INFO:tensorflow:loss = 0.04775357, step = 17300 (120.283 sec)
# INFO:tensorflow:global_step/sec: 2.05207
# INFO:tensorflow:loss = 0.027391355, step = 17400 (48.731 sec)
# INFO:tensorflow:global_step/sec: 2.04543
# INFO:tensorflow:loss = 0.058739033, step = 17500 (48.890 sec)
# INFO:tensorflow:global_step/sec: 2.03845
# INFO:tensorflow:loss = 0.040463, step = 17600 (49.056 sec)
# INFO:tensorflow:global_step/sec: 2.05124
# INFO:tensorflow:loss = 0.026635837, step = 17700 (48.751 sec)
# INFO:tensorflow:global_step/sec: 2.05373
# INFO:tensorflow:loss = 0.051676195, step = 17800 (48.692 sec)
# INFO:tensorflow:global_step/sec: 2.07501
# INFO:tensorflow:loss = 0.04026755, step = 17900 (48.192 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 18000...
# INFO:tensorflow:Saving checkpoints for 18000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 18000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T22:23:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.97628s
# INFO:tensorflow:Finished evaluation at 2025-01-05-22:26:53
# INFO:tensorflow:Saving dict for global step 18000: global_step = 18000, label/mean = -0.9426435, loss = 0.003309986, mae = 0.03276674, mse = 0.0033099847, prediction/mean = -0.9177972, rho = 0.98581266
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: cp_dl_models_04012025_distributed/model.ckpt-18000
# INFO:tensorflow:global_step/sec: 0.440005
# INFO:tensorflow:loss = 0.054781035, step = 18000 (227.270 sec)
# INFO:tensorflow:global_step/sec: 2.11652
# INFO:tensorflow:loss = 0.0256659, step = 18100 (47.248 sec)
# INFO:tensorflow:global_step/sec: 2.09389
# INFO:tensorflow:loss = 0.03027882, step = 18200 (47.758 sec)
# INFO:tensorflow:global_step/sec: 2.10781
# INFO:tensorflow:loss = 0.02844707, step = 18300 (47.442 sec)
# INFO:tensorflow:global_step/sec: 2.07301
# INFO:tensorflow:loss = 0.061365016, step = 18400 (48.239 sec)
# INFO:tensorflow:global_step/sec: 2.03829
# INFO:tensorflow:loss = 0.04124084, step = 18500 (49.060 sec)
# INFO:tensorflow:global_step/sec: 2.0602
# INFO:tensorflow:loss = 0.05904604, step = 18600 (48.540 sec)
# INFO:tensorflow:global_step/sec: 2.03837
# INFO:tensorflow:loss = 0.044707656, step = 18700 (49.059 sec)
# INFO:tensorflow:global_step/sec: 2.01608
# INFO:tensorflow:loss = 0.058906637, step = 18800 (49.601 sec)
# INFO:tensorflow:global_step/sec: 0.948825
# INFO:tensorflow:loss = 0.0681767, step = 18900 (105.394 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 19000...
# INFO:tensorflow:Saving checkpoints for 19000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 19000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T22:36:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-19000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.93122s
# INFO:tensorflow:Finished evaluation at 2025-01-05-22:39:14
# INFO:tensorflow:Saving dict for global step 19000: global_step = 19000, label/mean = -0.9426435, loss = 0.001476183, mae = 0.021426903, mse = 0.001476183, prediction/mean = -0.93451124, rho = 0.99131316
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19000: cp_dl_models_04012025_distributed/model.ckpt-19000
# INFO:tensorflow:global_step/sec: 0.401664
# INFO:tensorflow:loss = 0.053027764, step = 19000 (248.964 sec)
# INFO:tensorflow:global_step/sec: 2.02042
# INFO:tensorflow:loss = 0.035822134, step = 19100 (49.495 sec)
# INFO:tensorflow:global_step/sec: 2.00893
# INFO:tensorflow:loss = 0.07062855, step = 19200 (49.778 sec)
# INFO:tensorflow:global_step/sec: 1.9827
# INFO:tensorflow:loss = 0.0682055, step = 19300 (50.436 sec)
# INFO:tensorflow:global_step/sec: 2.0242
# INFO:tensorflow:loss = 0.063499436, step = 19400 (49.402 sec)
# INFO:tensorflow:global_step/sec: 2.05748
# INFO:tensorflow:loss = 0.06008376, step = 19500 (48.603 sec)
# INFO:tensorflow:global_step/sec: 2.03179
# INFO:tensorflow:loss = 0.10774682, step = 19600 (49.217 sec)
# INFO:tensorflow:global_step/sec: 2.03065
# INFO:tensorflow:loss = 0.084418036, step = 19700 (49.246 sec)
# INFO:tensorflow:global_step/sec: 2.06197
# INFO:tensorflow:loss = 0.06058798, step = 19800 (48.497 sec)
# INFO:tensorflow:global_step/sec: 2.07652
# INFO:tensorflow:loss = 0.05493365, step = 19900 (48.157 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20000...
# INFO:tensorflow:Saving checkpoints for 20000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T22:47:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.16494s
# INFO:tensorflow:Finished evaluation at 2025-01-05-22:50:24
# INFO:tensorflow:Saving dict for global step 20000: global_step = 20000, label/mean = -0.94264466, loss = 0.009606967, mae = 0.08759222, mse = 0.009606967, prediction/mean = -0.86383116, rho = 0.9912275
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: cp_dl_models_04012025_distributed/model.ckpt-20000
# INFO:tensorflow:global_step/sec: 0.440187
# INFO:tensorflow:loss = 0.1044414, step = 20000 (227.176 sec)
# INFO:tensorflow:global_step/sec: 2.06455
# INFO:tensorflow:loss = 0.058320202, step = 20100 (48.437 sec)
# INFO:tensorflow:global_step/sec: 2.06155
# INFO:tensorflow:loss = 0.04100034, step = 20200 (48.508 sec)
# INFO:tensorflow:global_step/sec: 2.03695
# INFO:tensorflow:loss = 0.06575687, step = 20300 (49.093 sec)
# INFO:tensorflow:global_step/sec: 2.04768
# INFO:tensorflow:loss = 0.019761711, step = 20400 (48.836 sec)
# INFO:tensorflow:global_step/sec: 2.05379
# INFO:tensorflow:loss = 0.06518658, step = 20500 (48.690 sec)
# INFO:tensorflow:global_step/sec: 2.07069
# INFO:tensorflow:loss = 0.051555194, step = 20600 (48.294 sec)
# INFO:tensorflow:global_step/sec: 2.07773
# INFO:tensorflow:loss = 0.03557829, step = 20700 (48.129 sec)
# INFO:tensorflow:global_step/sec: 2.05758
# INFO:tensorflow:loss = 0.034872636, step = 20800 (48.601 sec)
# INFO:tensorflow:global_step/sec: 2.06922
# INFO:tensorflow:loss = 0.024577662, step = 20900 (48.327 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 21000...
# INFO:tensorflow:Saving checkpoints for 21000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 21000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-05T22:58:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-21000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.56143s
# INFO:tensorflow:Finished evaluation at 2025-01-05-23:01:38
# INFO:tensorflow:Saving dict for global step 21000: global_step = 21000, label/mean = -0.9426438, loss = 0.0018796562, mae = 0.020016532, mse = 0.0018796563, prediction/mean = -0.9293596, rho = 0.9886232
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 21000: cp_dl_models_04012025_distributed/model.ckpt-21000
# INFO:tensorflow:global_step/sec: 0.42239
# ...
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 43000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T03:05:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-43000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 183.43514s
# INFO:tensorflow:Finished evaluation at 2025-01-06-03:08:49
# INFO:tensorflow:Saving dict for global step 43000: global_step = 43000, label/mean = -0.9426437, loss = 0.0044818195, mae = 0.03706657, mse = 0.0044818236, prediction/mean = -0.9154334, rho = 0.98685914
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 43000: cp_dl_models_04012025_distributed/model.ckpt-43000
# INFO:tensorflow:global_step/sec: 0.427153
# INFO:tensorflow:loss = 0.03437788, step = 43000 (234.108 sec)
# INFO:tensorflow:global_step/sec: 2.07173
# INFO:tensorflow:loss = 0.0105234645, step = 43100 (48.269 sec)
# INFO:tensorflow:global_step/sec: 2.07961
# INFO:tensorflow:loss = 0.04216212, step = 43200 (48.087 sec)
# INFO:tensorflow:global_step/sec: 2.08498
# INFO:tensorflow:loss = 0.07027987, step = 43300 (47.962 sec)
# INFO:tensorflow:global_step/sec: 2.05851
# INFO:tensorflow:loss = 0.046440817, step = 43400 (48.579 sec)
# INFO:tensorflow:global_step/sec: 2.08815
# INFO:tensorflow:loss = 0.030691072, step = 43500 (47.889 sec)
# INFO:tensorflow:global_step/sec: 2.07016
# INFO:tensorflow:loss = 0.0379694, step = 43600 (48.305 sec)
# INFO:tensorflow:global_step/sec: 2.06952
# INFO:tensorflow:loss = 0.04971212, step = 43700 (48.321 sec)
# INFO:tensorflow:global_step/sec: 2.0655
# INFO:tensorflow:loss = 0.09797064, step = 43800 (48.414 sec)
# INFO:tensorflow:global_step/sec: 2.05534
# INFO:tensorflow:loss = 0.0768086, step = 43900 (48.654 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 44000...
# INFO:tensorflow:Saving checkpoints for 44000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 44000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T03:16:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.83300s
# INFO:tensorflow:Finished evaluation at 2025-01-06-03:19:51
# INFO:tensorflow:Saving dict for global step 44000: global_step = 44000, label/mean = -0.94243103, loss = 0.002742603, mae = 0.034485392, mse = 0.0027426041, prediction/mean = -0.9163147, rho = 0.98936665
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: cp_dl_models_04012025_distributed/model.ckpt-44000
# INFO:tensorflow:global_step/sec: 0.438831
# INFO:tensorflow:loss = 0.068305545, step = 44000 (227.878 sec)
# INFO:tensorflow:global_step/sec: 2.06448
# INFO:tensorflow:loss = 0.08212453, step = 44100 (48.438 sec)
# INFO:tensorflow:global_step/sec: 2.03925
# INFO:tensorflow:loss = 0.046927888, step = 44200 (49.038 sec)
# INFO:tensorflow:global_step/sec: 2.04835
# INFO:tensorflow:loss = 0.036545217, step = 44300 (48.819 sec)
# INFO:tensorflow:global_step/sec: 2.05712
# INFO:tensorflow:loss = 0.023601022, step = 44400 (48.612 sec)
# INFO:tensorflow:global_step/sec: 2.08402
# INFO:tensorflow:loss = 0.05223225, step = 44500 (47.983 sec)
# INFO:tensorflow:global_step/sec: 2.07708
# INFO:tensorflow:loss = 0.06178344, step = 44600 (48.145 sec)
# INFO:tensorflow:global_step/sec: 2.03397
# INFO:tensorflow:loss = 0.04303643, step = 44700 (49.164 sec)
# INFO:tensorflow:global_step/sec: 2.03284
# INFO:tensorflow:loss = 0.038857155, step = 44800 (49.192 sec)
# INFO:tensorflow:global_step/sec: 2.02736
# INFO:tensorflow:loss = 0.025220372, step = 44900 (49.326 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 45000...
# INFO:tensorflow:Saving checkpoints for 45000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 45000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T03:28:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-45000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.28122s
# INFO:tensorflow:Finished evaluation at 2025-01-06-03:30:59
# INFO:tensorflow:Saving dict for global step 45000: global_step = 45000, label/mean = -0.9426437, loss = 0.0031459015, mae = 0.0418284, mse = 0.0031459, prediction/mean = -0.90645915, rho = 0.9914918
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45000: cp_dl_models_04012025_distributed/model.ckpt-45000
# INFO:tensorflow:global_step/sec: 0.43655
# INFO:tensorflow:loss = 0.04834953, step = 45000 (229.070 sec)
# INFO:tensorflow:global_step/sec: 2.04106
# INFO:tensorflow:loss = 0.03516233, step = 45100 (48.993 sec)
# INFO:tensorflow:global_step/sec: 2.0409
# INFO:tensorflow:loss = 0.056567207, step = 45200 (48.999 sec)
# INFO:tensorflow:global_step/sec: 2.03125
# INFO:tensorflow:loss = 0.1289108, step = 45300 (49.231 sec)
# INFO:tensorflow:global_step/sec: 2.02933
# INFO:tensorflow:loss = 0.022850316, step = 45400 (49.277 sec)
# INFO:tensorflow:global_step/sec: 2.05858
# INFO:tensorflow:loss = 0.044883043, step = 45500 (48.578 sec)
# INFO:tensorflow:global_step/sec: 2.0332
# INFO:tensorflow:loss = 0.028674077, step = 45600 (49.183 sec)
# INFO:tensorflow:global_step/sec: 2.04858
# INFO:tensorflow:loss = 0.051399533, step = 45700 (48.815 sec)
# INFO:tensorflow:global_step/sec: 2.01681
# INFO:tensorflow:loss = 0.019564131, step = 45800 (49.583 sec)
# INFO:tensorflow:global_step/sec: 2.05449
# INFO:tensorflow:loss = 0.07004364, step = 45900 (48.674 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 46000...
# INFO:tensorflow:Saving checkpoints for 46000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 46000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T03:39:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-46000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.99709s
# INFO:tensorflow:Finished evaluation at 2025-01-06-03:42:11
# INFO:tensorflow:Saving dict for global step 46000: global_step = 46000, label/mean = -0.9426441, loss = 0.0025937685, mae = 0.037273835, mse = 0.0025937662, prediction/mean = -0.90690786, rho = 0.99192154
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46000: cp_dl_models_04012025_distributed/model.ckpt-46000
# INFO:tensorflow:global_step/sec: 0.433412
# INFO:tensorflow:loss = 0.074479975, step = 46000 (230.727 sec)
# INFO:tensorflow:global_step/sec: 2.03981
# INFO:tensorflow:loss = 0.05909236, step = 46100 (49.024 sec)
# INFO:tensorflow:global_step/sec: 2.03192
# INFO:tensorflow:loss = 0.09243636, step = 46200 (49.215 sec)
# INFO:tensorflow:global_step/sec: 2.04662
# INFO:tensorflow:loss = 0.05608128, step = 46300 (48.861 sec)
# INFO:tensorflow:global_step/sec: 2.02064
# INFO:tensorflow:loss = 0.050358742, step = 46400 (49.489 sec)
# INFO:tensorflow:global_step/sec: 2.03798
# INFO:tensorflow:loss = 0.02886239, step = 46500 (49.069 sec)
# INFO:tensorflow:global_step/sec: 2.03325
# INFO:tensorflow:loss = 0.07272031, step = 46600 (49.182 sec)
# INFO:tensorflow:global_step/sec: 2.03756
# INFO:tensorflow:loss = 0.025047427, step = 46700 (49.079 sec)
# INFO:tensorflow:global_step/sec: 2.08244
# INFO:tensorflow:loss = 0.08342788, step = 46800 (48.020 sec)
# INFO:tensorflow:global_step/sec: 2.09556
# INFO:tensorflow:loss = 0.040421084, step = 46900 (47.720 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 47000...
# INFO:tensorflow:Saving checkpoints for 47000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 47000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T03:50:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-47000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.21371s
# INFO:tensorflow:Finished evaluation at 2025-01-06-03:53:18
# INFO:tensorflow:Saving dict for global step 47000: global_step = 47000, label/mean = -0.94264394, loss = 0.005250463, mae = 0.0508025, mse = 0.005250466, prediction/mean = -0.9015484, rho = 0.98845017
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47000: cp_dl_models_04012025_distributed/model.ckpt-47000
# INFO:tensorflow:global_step/sec: 0.43994
# INFO:tensorflow:loss = 0.05176609, step = 47000 (227.303 sec)
# INFO:tensorflow:global_step/sec: 2.09939
# INFO:tensorflow:loss = 0.021672726, step = 47100 (47.633 sec)
# INFO:tensorflow:global_step/sec: 2.10562
# INFO:tensorflow:loss = 0.06611003, step = 47200 (47.491 sec)
# INFO:tensorflow:global_step/sec: 2.08634
# INFO:tensorflow:loss = 0.035239138, step = 47300 (47.931 sec)
# INFO:tensorflow:global_step/sec: 2.07397
# INFO:tensorflow:loss = 0.04643853, step = 47400 (48.217 sec)
# INFO:tensorflow:global_step/sec: 2.07553
# INFO:tensorflow:loss = 0.06270882, step = 47500 (48.180 sec)
# INFO:tensorflow:global_step/sec: 2.05413
# INFO:tensorflow:loss = 0.027868748, step = 47600 (48.683 sec)
# INFO:tensorflow:global_step/sec: 2.05754
# INFO:tensorflow:loss = 0.05085076, step = 47700 (48.601 sec)
# INFO:tensorflow:global_step/sec: 2.06511
# INFO:tensorflow:loss = 0.07297888, step = 47800 (48.424 sec)
# INFO:tensorflow:global_step/sec: 2.07118
# INFO:tensorflow:loss = 0.028071547, step = 47900 (48.281 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 48000...
# INFO:tensorflow:Saving checkpoints for 48000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 48000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T04:01:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-48000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.06872s
# INFO:tensorflow:Finished evaluation at 2025-01-06-04:04:40
# INFO:tensorflow:Saving dict for global step 48000: global_step = 48000, label/mean = -0.9426435, loss = 0.0049883667, mae = 0.0551538, mse = 0.0049883644, prediction/mean = -0.8933374, rho = 0.98971564
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48000: cp_dl_models_04012025_distributed/model.ckpt-48000
# INFO:tensorflow:global_step/sec: 0.403386
# INFO:tensorflow:loss = 0.05034881, step = 48000 (247.904 sec)
# INFO:tensorflow:global_step/sec: 2.02337
# INFO:tensorflow:loss = 0.048994772, step = 48100 (49.421 sec)
# INFO:tensorflow:global_step/sec: 2.02703
# INFO:tensorflow:loss = 0.015844217, step = 48200 (49.334 sec)
# INFO:tensorflow:global_step/sec: 2.01947
# INFO:tensorflow:loss = 0.02874619, step = 48300 (49.517 sec)
# INFO:tensorflow:global_step/sec: 2.02741
# INFO:tensorflow:loss = 0.054159522, step = 48400 (49.325 sec)
# INFO:tensorflow:global_step/sec: 2.03537
# INFO:tensorflow:loss = 0.0854177, step = 48500 (49.130 sec)
# INFO:tensorflow:global_step/sec: 1.14562
# INFO:tensorflow:loss = 0.018674087, step = 48600 (87.289 sec)
# INFO:tensorflow:global_step/sec: 2.02722
# INFO:tensorflow:loss = 0.030964142, step = 48700 (49.329 sec)
# INFO:tensorflow:global_step/sec: 2.03625
# INFO:tensorflow:loss = 0.049935322, step = 48800 (49.109 sec)
# INFO:tensorflow:global_step/sec: 2.03266
# INFO:tensorflow:loss = 0.039879978, step = 48900 (49.197 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 49000...
# INFO:tensorflow:Saving checkpoints for 49000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 49000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T04:13:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-49000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 176.93598s
# INFO:tensorflow:Finished evaluation at 2025-01-06-04:16:29
# INFO:tensorflow:Saving dict for global step 49000: global_step = 49000, label/mean = -0.9426438, loss = 0.0051539717, mae = 0.04253591, mse = 0.005153971, prediction/mean = -0.913078, rho = 0.9749425
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49000: cp_dl_models_04012025_distributed/model.ckpt-49000
# INFO:tensorflow:global_step/sec: 0.439035
# INFO:tensorflow:loss = 0.061306532, step = 49000 (227.771 sec)
# INFO:tensorflow:global_step/sec: 2.03747
# INFO:tensorflow:loss = 0.06338942, step = 49100 (49.081 sec)
# INFO:tensorflow:global_step/sec: 2.05275
# INFO:tensorflow:loss = 0.035473596, step = 49200 (48.715 sec)
# INFO:tensorflow:global_step/sec: 2.06752
# INFO:tensorflow:loss = 0.0724218, step = 49300 (48.367 sec)
# INFO:tensorflow:global_step/sec: 2.07454
# INFO:tensorflow:loss = 0.052867487, step = 49400 (48.204 sec)
# INFO:tensorflow:global_step/sec: 2.05863
# INFO:tensorflow:loss = 0.03531324, step = 49500 (48.576 sec)
# INFO:tensorflow:global_step/sec: 2.061
# INFO:tensorflow:loss = 0.023857497, step = 49600 (48.520 sec)
# INFO:tensorflow:global_step/sec: 2.0506
# INFO:tensorflow:loss = 0.04967358, step = 49700 (48.767 sec)
# INFO:tensorflow:global_step/sec: 2.05086
# INFO:tensorflow:loss = 0.024042306, step = 49800 (48.760 sec)
# INFO:tensorflow:global_step/sec: 2.0465
# INFO:tensorflow:loss = 0.010390223, step = 49900 (48.864 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 50000...
# INFO:tensorflow:Saving checkpoints for 50000 into cp_dl_models_04012025_distributed/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 50000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-01-06T04:24:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from cp_dl_models_04012025_distributed/model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 177.02485s
# INFO:tensorflow:Finished evaluation at 2025-01-06-04:27:36
# INFO:tensorflow:Saving dict for global step 50000: global_step = 50000, label/mean = -0.9426435, loss = 0.0021550558, mae = 0.027763668, mse = 0.0021550532, prediction/mean = -0.93601555, rho = 0.9863526
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50000: cp_dl_models_04012025_distributed/model.ckpt-50000
# INFO:tensorflow:Loss for final step: 0.052855067.
# CPU times: user 2d 14h 10min 26s, sys: 8h 36min 23s, total: 2d 22h 46min 50s
# Wall time: 9h 25min 22s
